# %%
import os
import random
import librosa
import numpy as np
import soundfile as sf
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift, Normalize, Gain

# Define the augmentation pipeline
augmenter = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_shift=-0.5, max_shift=0.5, p=0.5),
    Normalize(p=0.5),
    Gain(min_gain_in_db=-12, max_gain_in_db=12, p=0.5),
])

# Directory paths
input_directory = '/home/jupyter/advanced/audio'
output_directory = '/home/jupyter/augmentedaudio'

# Create output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Function to load and save audio files
def augment_audio_file(file_path, output_path, augmenter):
    # Load audio file
    samples, sample_rate = librosa.load(file_path, sr=None, mono=True)
    # Apply augmentation
    augmented_samples = augmenter(samples=samples, sample_rate=sample_rate)
    # Save augmented audio file
    sf.write(output_path, augmented_samples, sample_rate)

# List all .wav files in the input directory
wav_files = [f for f in os.listdir(input_directory) if f.endswith('.wav')]

# Randomly augment a subset of files
for file_name in wav_files:
    file_path = os.path.join(input_directory, file_name)
    output_path = os.path.join(output_directory, file_name)
    
    # Randomly decide whether to augment this file
    if random.random() < 0.5:  # 50% chance to augment
        augment_audio_file(file_path, output_path, augmenter)
        augmented = True
    else:
        # Just copy the file without augmentation
        sf.write(output_path, *librosa.load(file_path, sr=None, mono=True))
        augmented = False
    
    print(f"{file_name} augmented, {augmented}")

print(f"Augmentation completed. Augmented files are saved in {output_directory}")
# Out:
# audio_0.wav augmented, True
# audio_1.wav augmented, True
# audio_10.wav augmented, False
# audio_100.wav augmented, False
# audio_1000.wav augmented, False
# audio_1001.wav augmented, False
# audio_1002.wav augmented, False
# audio_1003.wav augmented, False
# audio_1004.wav augmented, False
# audio_1005.wav augmented, False
# audio_1006.wav augmented, False
# audio_1007.wav augmented, False
# audio_1008.wav augmented, True
# audio_1009.wav augmented, True
# audio_101.wav augmented, False
# audio_1010.wav augmented, True
# audio_1011.wav augmented, False
# audio_1012.wav augmented, False
# audio_1013.wav augmented, True
# audio_1014.wav augmented, False
# audio_1015.wav augmented, False
# audio_1016.wav augmented, True
# audio_1017.wav augmented, False
# audio_1018.wav augmented, False
# audio_1019.wav augmented, True
# audio_102.wav augmented, False
# audio_1020.wav augmented, False
# audio_1021.wav augmented, False
# audio_1022.wav augmented, True
# audio_1023.wav augmented, True
# audio_1024.wav augmented, False
# audio_1025.wav augmented, False
# audio_1026.wav augmented, True
# audio_1027.wav augmented, True
# audio_1028.wav augmented, False
# audio_1029.wav augmented, False
# audio_103.wav augmented, False
# audio_1030.wav augmented, True
# audio_1031.wav augmented, False
# audio_1032.wav augmented, True
# audio_1033.wav augmented, True
# audio_1034.wav augmented, False
# audio_1035.wav augmented, False
# audio_1036.wav augmented, True
# audio_1037.wav augmented, False
# audio_1038.wav augmented, True
# audio_1039.wav augmented, False
# audio_104.wav augmented, True
# audio_1040.wav augmented, False
# audio_1041.wav augmented, False
# audio_1042.wav augmented, True
# audio_1043.wav augmented, True
# audio_1044.wav augmented, True
# audio_1045.wav augmented, False
# audio_1046.wav augmented, True
# audio_1047.wav augmented, False
# audio_1048.wav augmented, False
# audio_1049.wav augmented, False
# audio_105.wav augmented, True
# audio_1050.wav augmented, False
# audio_1051.wav augmented, True
# audio_1052.wav augmented, True
# audio_1053.wav augmented, True
# audio_1054.wav augmented, False
# audio_1055.wav augmented, True
# audio_1056.wav augmented, True
# audio_1057.wav augmented, False
# audio_1058.wav augmented, False
# audio_1059.wav augmented, False
# audio_106.wav augmented, False
# audio_1060.wav augmented, False
# audio_1061.wav augmented, True
# audio_1062.wav augmented, True
# audio_1063.wav augmented, False
# audio_1064.wav augmented, False
# audio_1065.wav augmented, True
# audio_1066.wav augmented, True
# audio_1067.wav augmented, False
# audio_1068.wav augmented, False
# audio_1069.wav augmented, True
# audio_107.wav augmented, False
# audio_1070.wav augmented, False
# audio_1071.wav augmented, False
# audio_1072.wav augmented, False
# audio_1073.wav augmented, True
# audio_1074.wav augmented, True
# audio_1075.wav augmented, True
# audio_1076.wav augmented, True
# audio_1077.wav augmented, False
# audio_1078.wav augmented, True
# audio_1079.wav augmented, False
# audio_108.wav augmented, False
# audio_1080.wav augmented, True
# audio_1081.wav augmented, True
# audio_1082.wav augmented, True
# audio_1083.wav augmented, True
# audio_1084.wav augmented, True
# audio_1085.wav augmented, True
# audio_1086.wav augmented, True
# audio_1087.wav augmented, True
# audio_1088.wav augmented, True
# audio_1089.wav augmented, True
# audio_109.wav augmented, True
# audio_1090.wav augmented, True
# audio_1091.wav augmented, False
# audio_1092.wav augmented, False
# audio_1093.wav augmented, True
# audio_1094.wav augmented, False
# audio_1095.wav augmented, False
# audio_1096.wav augmented, True
# audio_1097.wav augmented, False
# audio_1098.wav augmented, False
# audio_1099.wav augmented, True
# audio_11.wav augmented, False
# audio_110.wav augmented, True
# audio_1100.wav augmented, False
# audio_1101.wav augmented, False
# audio_1102.wav augmented, False
# audio_1103.wav augmented, True
# audio_1104.wav augmented, True
# audio_1105.wav augmented, False
# audio_1106.wav augmented, True
# audio_1107.wav augmented, True
# audio_1108.wav augmented, True
# audio_1109.wav augmented, True
# audio_111.wav augmented, True
# audio_1110.wav augmented, True
# audio_1111.wav augmented, False
# audio_1112.wav augmented, True
# audio_1113.wav augmented, True
# audio_1114.wav augmented, False
# audio_1115.wav augmented, True
# audio_1116.wav augmented, True
# audio_1117.wav augmented, True
# audio_1118.wav augmented, False
# audio_1119.wav augmented, True
# audio_112.wav augmented, False
# audio_1120.wav augmented, False
# audio_1121.wav augmented, False
# audio_1122.wav augmented, False
# audio_1123.wav augmented, True
# audio_1124.wav augmented, True
# audio_1125.wav augmented, True
# audio_1126.wav augmented, True
# audio_1127.wav augmented, True
# audio_1128.wav augmented, False
# audio_1129.wav augmented, True
# audio_113.wav augmented, False
# audio_1130.wav augmented, False
# audio_1131.wav augmented, False
# audio_1132.wav augmented, True
# audio_1133.wav augmented, True
# audio_1134.wav augmented, False
# audio_1135.wav augmented, False
# audio_1136.wav augmented, False
# audio_1137.wav augmented, True
# audio_1138.wav augmented, False
# audio_1139.wav augmented, False
# audio_114.wav augmented, False
# audio_1140.wav augmented, False
# audio_1141.wav augmented, False
# audio_1142.wav augmented, False
# audio_1143.wav augmented, False
# audio_1144.wav augmented, False
# audio_1145.wav augmented, True
# audio_1146.wav augmented, False
# audio_1147.wav augmented, False
# audio_1148.wav augmented, False
# audio_1149.wav augmented, True
# audio_115.wav augmented, False
# audio_1150.wav augmented, True
# audio_1151.wav augmented, True
# audio_1152.wav augmented, True
# audio_1153.wav augmented, True
# audio_1154.wav augmented, False
# audio_1155.wav augmented, True
# audio_1156.wav augmented, True
# audio_1157.wav augmented, False
# audio_1158.wav augmented, True
# audio_1159.wav augmented, False
# audio_116.wav augmented, True
# audio_1160.wav augmented, True
# audio_1161.wav augmented, False
# audio_1162.wav augmented, True
# audio_1163.wav augmented, False
# audio_1164.wav augmented, True
# audio_1165.wav augmented, True
# audio_1166.wav augmented, False
# audio_1167.wav augmented, True
# audio_1168.wav augmented, True
# audio_1169.wav augmented, True
# audio_117.wav augmented, True
# audio_1170.wav augmented, True
# audio_1171.wav augmented, True
# audio_1172.wav augmented, False
# audio_1173.wav augmented, False
# audio_1174.wav augmented, True
# audio_1175.wav augmented, False
# audio_1176.wav augmented, False
# audio_1177.wav augmented, False
# audio_1178.wav augmented, True
# audio_1179.wav augmented, True
# audio_118.wav augmented, False
# audio_1180.wav augmented, False
# audio_1181.wav augmented, True
# audio_1182.wav augmented, False
# audio_1183.wav augmented, False
# audio_1184.wav augmented, True
# audio_1185.wav augmented, False
# audio_1186.wav augmented, False
# audio_1187.wav augmented, True
# audio_1188.wav augmented, True
# audio_1189.wav augmented, False
# audio_119.wav augmented, False
# audio_1190.wav augmented, False
# audio_1191.wav augmented, True
# audio_1192.wav augmented, True
# audio_1193.wav augmented, False
# audio_1194.wav augmented, False
# audio_1195.wav augmented, True
# audio_1196.wav augmented, True
# audio_1197.wav augmented, True
# audio_1198.wav augmented, False
# audio_1199.wav augmented, False
# audio_12.wav augmented, True
# audio_120.wav augmented, True
# audio_1200.wav augmented, True
# audio_1201.wav augmented, False
# audio_1202.wav augmented, False
# audio_1203.wav augmented, True
# audio_1204.wav augmented, False
# audio_1205.wav augmented, False
# audio_1206.wav augmented, False
# audio_1207.wav augmented, False
# audio_1208.wav augmented, True
# audio_1209.wav augmented, True
# audio_121.wav augmented, False
# audio_1210.wav augmented, True
# audio_1211.wav augmented, True
# audio_1212.wav augmented, False
# audio_1213.wav augmented, True
# audio_1214.wav augmented, True
# audio_1215.wav augmented, True
# audio_1216.wav augmented, False
# audio_1217.wav augmented, True
# audio_1218.wav augmented, True
# audio_1219.wav augmented, True
# audio_122.wav augmented, True
# audio_1220.wav augmented, False
# audio_1221.wav augmented, True
# audio_1222.wav augmented, False
# audio_1223.wav augmented, True
# audio_1224.wav augmented, True
# audio_1225.wav augmented, False
# audio_1226.wav augmented, True
# audio_1227.wav augmented, False
# audio_1228.wav augmented, True
# audio_1229.wav augmented, False
# audio_123.wav augmented, False
# audio_1230.wav augmented, False
# audio_1231.wav augmented, True
# audio_1232.wav augmented, False
# audio_1233.wav augmented, True
# audio_1234.wav augmented, False
# audio_1235.wav augmented, True
# audio_1236.wav augmented, False
# audio_1237.wav augmented, True
# audio_1238.wav augmented, True
# audio_1239.wav augmented, False
# audio_124.wav augmented, True
# audio_1240.wav augmented, True
# audio_1241.wav augmented, True
# audio_1242.wav augmented, False
# audio_1243.wav augmented, True
# audio_1244.wav augmented, False
# audio_1245.wav augmented, True
# audio_1246.wav augmented, False
# audio_1247.wav augmented, True
# audio_1248.wav augmented, True
# audio_1249.wav augmented, False
# audio_125.wav augmented, False
# audio_1250.wav augmented, True
# audio_1251.wav augmented, False
# audio_1252.wav augmented, False
# audio_1253.wav augmented, True
# audio_1254.wav augmented, False
# audio_1255.wav augmented, False
# audio_1256.wav augmented, True
# audio_1257.wav augmented, False
# audio_1258.wav augmented, False
# audio_1259.wav augmented, False
# audio_126.wav augmented, True
# audio_1260.wav augmented, True
# audio_1261.wav augmented, True
# audio_1262.wav augmented, True
# audio_1263.wav augmented, True
# audio_1264.wav augmented, True
# audio_1265.wav augmented, True
# audio_1266.wav augmented, False
# audio_1267.wav augmented, False
# audio_1268.wav augmented, False
# audio_1269.wav augmented, True
# audio_127.wav augmented, False
# audio_1270.wav augmented, True
# audio_1271.wav augmented, False
# audio_1272.wav augmented, False
# audio_1273.wav augmented, True
# audio_1274.wav augmented, True
# audio_1275.wav augmented, False
# audio_1276.wav augmented, True
# audio_1277.wav augmented, True
# audio_1278.wav augmented, False
# audio_1279.wav augmented, True
# audio_128.wav augmented, False
# audio_1280.wav augmented, True
# audio_1281.wav augmented, True
# audio_1282.wav augmented, True
# audio_1283.wav augmented, False
# audio_1284.wav augmented, False
# audio_1285.wav augmented, True
# audio_1286.wav augmented, True
# audio_1287.wav augmented, False
# audio_1288.wav augmented, True
# audio_1289.wav augmented, True
# audio_129.wav augmented, False
# audio_1290.wav augmented, True
# audio_1291.wav augmented, False
# audio_1292.wav augmented, False
# audio_1293.wav augmented, False
# audio_1294.wav augmented, True
# audio_1295.wav augmented, False
# audio_1296.wav augmented, True
# audio_1297.wav augmented, True
# audio_1298.wav augmented, True
# audio_1299.wav augmented, False
# audio_13.wav augmented, True
# audio_130.wav augmented, False
# audio_1300.wav augmented, False
# audio_1301.wav augmented, True
# audio_1302.wav augmented, False
# audio_1303.wav augmented, False
# audio_1304.wav augmented, True
# audio_1305.wav augmented, True
# audio_1306.wav augmented, True
# audio_1307.wav augmented, True
# audio_1308.wav augmented, True
# audio_1309.wav augmented, False
# audio_131.wav augmented, False
# audio_1310.wav augmented, True
# audio_1311.wav augmented, False
# audio_1312.wav augmented, False
# audio_1313.wav augmented, True
# audio_1314.wav augmented, True
# audio_1315.wav augmented, False
# audio_1316.wav augmented, True
# audio_1317.wav augmented, True
# audio_1318.wav augmented, True
# audio_1319.wav augmented, False
# audio_132.wav augmented, False
# audio_1320.wav augmented, False
# audio_1321.wav augmented, False
# audio_1322.wav augmented, False
# audio_1323.wav augmented, True
# audio_1324.wav augmented, True
# audio_1325.wav augmented, False
# audio_1326.wav augmented, True
# audio_1327.wav augmented, True
# audio_1328.wav augmented, False
# audio_1329.wav augmented, True
# audio_133.wav augmented, True
# audio_1330.wav augmented, True
# audio_1331.wav augmented, True
# audio_1332.wav augmented, False
# audio_1333.wav augmented, False
# audio_1334.wav augmented, True
# audio_1335.wav augmented, False
# audio_1336.wav augmented, False
# audio_1337.wav augmented, True
# audio_1338.wav augmented, False
# audio_1339.wav augmented, False
# audio_134.wav augmented, False
# audio_1340.wav augmented, False
# audio_1341.wav augmented, True
# audio_1342.wav augmented, True
# audio_1343.wav augmented, True
# audio_1344.wav augmented, True
# audio_1345.wav augmented, False
# audio_1346.wav augmented, True
# audio_1347.wav augmented, True
# audio_1348.wav augmented, False
# audio_1349.wav augmented, False
# audio_135.wav augmented, True
# audio_1350.wav augmented, False
# audio_1351.wav augmented, True
# audio_1352.wav augmented, True
# audio_1353.wav augmented, True
# audio_1354.wav augmented, False
# audio_1355.wav augmented, False
# audio_1356.wav augmented, True
# audio_1357.wav augmented, True
# audio_1358.wav augmented, False
# audio_1359.wav augmented, True
# audio_136.wav augmented, False
# audio_1360.wav augmented, True
# audio_1361.wav augmented, False
# audio_1362.wav augmented, True
# audio_1363.wav augmented, False
# audio_1364.wav augmented, False
# audio_1365.wav augmented, True
# audio_1366.wav augmented, True
# audio_1367.wav augmented, True
# audio_1368.wav augmented, True
# audio_1369.wav augmented, False
# audio_137.wav augmented, True
# audio_1370.wav augmented, True
# audio_1371.wav augmented, False
# audio_1372.wav augmented, False
# audio_1373.wav augmented, True
# audio_1374.wav augmented, True
# audio_1375.wav augmented, False
# audio_1376.wav augmented, True
# audio_1377.wav augmented, True
# audio_1378.wav augmented, False
# audio_1379.wav augmented, False
# audio_138.wav augmented, True
# audio_1380.wav augmented, False
# audio_1381.wav augmented, False
# audio_1382.wav augmented, False
# audio_1383.wav augmented, False
# audio_1384.wav augmented, True
# audio_1385.wav augmented, True
# audio_1386.wav augmented, False
# audio_1387.wav augmented, False
# audio_1388.wav augmented, False
# audio_1389.wav augmented, True
# audio_139.wav augmented, True
# audio_1390.wav augmented, True
# audio_1391.wav augmented, True
# audio_1392.wav augmented, False
# audio_1393.wav augmented, True
# audio_1394.wav augmented, False
# audio_1395.wav augmented, True
# audio_1396.wav augmented, False
# audio_1397.wav augmented, True
# audio_1398.wav augmented, False
# audio_1399.wav augmented, True
# audio_14.wav augmented, False
# audio_140.wav augmented, False
# audio_1400.wav augmented, True
# audio_1401.wav augmented, False
# audio_1402.wav augmented, True
# audio_1403.wav augmented, False
# audio_1404.wav augmented, True
# audio_1405.wav augmented, True
# audio_1406.wav augmented, True
# audio_1407.wav augmented, False
# audio_1408.wav augmented, False
# audio_1409.wav augmented, True
# audio_141.wav augmented, True
# audio_1410.wav augmented, True
# audio_1411.wav augmented, False
# audio_1412.wav augmented, False
# audio_1413.wav augmented, True
# audio_1414.wav augmented, True
# audio_1415.wav augmented, False
# audio_1416.wav augmented, False
# audio_1417.wav augmented, True
# audio_1418.wav augmented, True
# audio_1419.wav augmented, False
# audio_142.wav augmented, False
# audio_1420.wav augmented, True
# audio_1421.wav augmented, True
# audio_1422.wav augmented, True
# audio_1423.wav augmented, False
# audio_1424.wav augmented, False
# audio_1425.wav augmented, True
# audio_1426.wav augmented, False
# audio_1427.wav augmented, False
# audio_1428.wav augmented, True
# audio_1429.wav augmented, True
# audio_143.wav augmented, True
# audio_1430.wav augmented, True
# audio_1431.wav augmented, True
# audio_1432.wav augmented, True
# audio_1433.wav augmented, True
# audio_1434.wav augmented, True
# audio_1435.wav augmented, True
# audio_1436.wav augmented, False
# audio_1437.wav augmented, True
# audio_1438.wav augmented, True
# audio_1439.wav augmented, False
# audio_144.wav augmented, False
# audio_1440.wav augmented, False
# audio_1441.wav augmented, True
# audio_1442.wav augmented, False
# audio_1443.wav augmented, False
# audio_1444.wav augmented, True
# audio_1445.wav augmented, False
# audio_1446.wav augmented, True
# audio_1447.wav augmented, True
# audio_1448.wav augmented, False
# audio_1449.wav augmented, False
# audio_145.wav augmented, False
# audio_1450.wav augmented, True
# audio_1451.wav augmented, True
# audio_1452.wav augmented, False
# audio_1453.wav augmented, True
# audio_1454.wav augmented, False
# audio_1455.wav augmented, False
# audio_1456.wav augmented, True
# audio_1457.wav augmented, True
# audio_1458.wav augmented, True
# audio_1459.wav augmented, True
# audio_146.wav augmented, True
# audio_1460.wav augmented, True
# audio_1461.wav augmented, False
# audio_1462.wav augmented, True
# audio_1463.wav augmented, True
# audio_1464.wav augmented, False
# audio_1465.wav augmented, True
# audio_1466.wav augmented, False
# audio_1467.wav augmented, True
# audio_1468.wav augmented, False
# audio_1469.wav augmented, False
# audio_147.wav augmented, False
# audio_1470.wav augmented, False
# audio_1471.wav augmented, False
# audio_1472.wav augmented, False
# audio_1473.wav augmented, True
# audio_1474.wav augmented, False
# audio_1475.wav augmented, True
# audio_1476.wav augmented, True
# audio_1477.wav augmented, False
# audio_1478.wav augmented, False
# audio_1479.wav augmented, True
# audio_148.wav augmented, False
# audio_1480.wav augmented, True
# audio_1481.wav augmented, True
# audio_1482.wav augmented, True
# audio_1483.wav augmented, True
# audio_1484.wav augmented, True
# audio_1485.wav augmented, False
# audio_1486.wav augmented, True
# audio_1487.wav augmented, False
# audio_1488.wav augmented, False
# audio_1489.wav augmented, True
# audio_149.wav augmented, True
# audio_1490.wav augmented, True
# audio_1491.wav augmented, False
# audio_1492.wav augmented, True
# audio_1493.wav augmented, True
# audio_1494.wav augmented, False
# audio_1495.wav augmented, True
# audio_1496.wav augmented, False
# audio_1497.wav augmented, False
# audio_1498.wav augmented, True
# audio_1499.wav augmented, False
# audio_15.wav augmented, False
# audio_150.wav augmented, True
# audio_1500.wav augmented, True
# audio_1501.wav augmented, True
# audio_1502.wav augmented, True
# audio_1503.wav augmented, True
# audio_1504.wav augmented, False
# audio_1505.wav augmented, True
# audio_1506.wav augmented, True
# audio_1507.wav augmented, True
# audio_1508.wav augmented, True
# audio_1509.wav augmented, False
# audio_151.wav augmented, True
# audio_1510.wav augmented, False
# audio_1511.wav augmented, True
# audio_1512.wav augmented, True
# audio_1513.wav augmented, True
# audio_1514.wav augmented, True
# audio_1515.wav augmented, False
# audio_1516.wav augmented, False
# audio_1517.wav augmented, True
# audio_1518.wav augmented, True
# audio_1519.wav augmented, True
# audio_152.wav augmented, False
# audio_1520.wav augmented, False
# audio_1521.wav augmented, True
# audio_1522.wav augmented, True
# audio_1523.wav augmented, True
# audio_1524.wav augmented, True
# audio_1525.wav augmented, False
# audio_1526.wav augmented, False
# audio_1527.wav augmented, False
# audio_1528.wav augmented, True
# audio_1529.wav augmented, False
# audio_153.wav augmented, True
# audio_1530.wav augmented, True
# audio_1531.wav augmented, False
# audio_1532.wav augmented, False
# audio_1533.wav augmented, True
# audio_1534.wav augmented, True
# audio_1535.wav augmented, False
# audio_1536.wav augmented, True
# audio_1537.wav augmented, False
# audio_1538.wav augmented, False
# audio_1539.wav augmented, True
# audio_154.wav augmented, False
# audio_1540.wav augmented, False
# audio_1541.wav augmented, True
# audio_1542.wav augmented, True
# audio_1543.wav augmented, True
# audio_1544.wav augmented, False
# audio_1545.wav augmented, False
# audio_1546.wav augmented, True
# audio_1547.wav augmented, False
# audio_1548.wav augmented, False
# audio_1549.wav augmented, False
# audio_155.wav augmented, False
# audio_1550.wav augmented, True
# audio_1551.wav augmented, False
# audio_1552.wav augmented, False
# audio_1553.wav augmented, True
# audio_1554.wav augmented, False
# audio_1555.wav augmented, False
# audio_1556.wav augmented, False
# audio_1557.wav augmented, False
# audio_1558.wav augmented, True
# audio_1559.wav augmented, True
# audio_156.wav augmented, False
# audio_1560.wav augmented, False
# audio_1561.wav augmented, True
# audio_1562.wav augmented, True
# audio_1563.wav augmented, False
# audio_1564.wav augmented, True
# audio_1565.wav augmented, True
# audio_1566.wav augmented, False
# audio_1567.wav augmented, True
# audio_1568.wav augmented, False
# audio_1569.wav augmented, False
# audio_157.wav augmented, True
# audio_1570.wav augmented, True
# audio_1571.wav augmented, False
# audio_1572.wav augmented, True
# audio_1573.wav augmented, True
# audio_1574.wav augmented, False
# audio_1575.wav augmented, True
# audio_1576.wav augmented, False
# audio_1577.wav augmented, False
# audio_1578.wav augmented, False
# audio_1579.wav augmented, True
# audio_158.wav augmented, True
# audio_1580.wav augmented, True
# audio_1581.wav augmented, False
# audio_1582.wav augmented, False
# audio_1583.wav augmented, True
# audio_1584.wav augmented, True
# audio_1585.wav augmented, False
# audio_1586.wav augmented, True
# audio_1587.wav augmented, False
# audio_1588.wav augmented, True
# audio_1589.wav augmented, False
# audio_159.wav augmented, False
# audio_1590.wav augmented, False
# audio_1591.wav augmented, True
# audio_1592.wav augmented, False
# audio_1593.wav augmented, False
# audio_1594.wav augmented, True
# audio_1595.wav augmented, False
# audio_1596.wav augmented, False
# audio_1597.wav augmented, True
# audio_1598.wav augmented, False
# audio_1599.wav augmented, True
# audio_16.wav augmented, True
# audio_160.wav augmented, True
# audio_1600.wav augmented, True
# audio_1601.wav augmented, True
# audio_1602.wav augmented, True
# audio_1603.wav augmented, False
# audio_1604.wav augmented, False
# audio_1605.wav augmented, True
# audio_1606.wav augmented, False
# audio_1607.wav augmented, False
# audio_1608.wav augmented, True
# audio_1609.wav augmented, False
# audio_161.wav augmented, False
# audio_1610.wav augmented, True
# audio_1611.wav augmented, False
# audio_1612.wav augmented, True
# audio_1613.wav augmented, False
# audio_1614.wav augmented, True
# audio_1615.wav augmented, False
# audio_1616.wav augmented, False
# audio_1617.wav augmented, False
# audio_1618.wav augmented, False
# audio_1619.wav augmented, False
# audio_162.wav augmented, True
# audio_1620.wav augmented, False
# audio_1621.wav augmented, False
# audio_1622.wav augmented, True
# audio_1623.wav augmented, True
# audio_1624.wav augmented, False
# audio_1625.wav augmented, False
# audio_1626.wav augmented, False
# audio_1627.wav augmented, False
# audio_1628.wav augmented, False
# audio_1629.wav augmented, False
# audio_163.wav augmented, True
# audio_1630.wav augmented, False
# audio_1631.wav augmented, False
# audio_1632.wav augmented, True
# audio_1633.wav augmented, True
# audio_1634.wav augmented, False
# audio_1635.wav augmented, False
# audio_1636.wav augmented, False
# audio_1637.wav augmented, True
# audio_1638.wav augmented, False
# audio_1639.wav augmented, False
# audio_164.wav augmented, False
# audio_1640.wav augmented, True
# audio_1641.wav augmented, True
# audio_1642.wav augmented, False
# audio_1643.wav augmented, False
# audio_1644.wav augmented, False
# audio_1645.wav augmented, True
# audio_1646.wav augmented, False
# audio_1647.wav augmented, True
# audio_1648.wav augmented, False
# audio_1649.wav augmented, False
# audio_165.wav augmented, False
# audio_1650.wav augmented, False
# audio_1651.wav augmented, True
# audio_1652.wav augmented, True
# audio_1653.wav augmented, True
# audio_1654.wav augmented, False
# audio_1655.wav augmented, False
# audio_1656.wav augmented, False
# audio_1657.wav augmented, True
# audio_1658.wav augmented, False
# audio_1659.wav augmented, False
# audio_166.wav augmented, False
# audio_1660.wav augmented, False
# audio_1661.wav augmented, False
# audio_1662.wav augmented, True
# audio_1663.wav augmented, True
# audio_1664.wav augmented, False
# audio_1665.wav augmented, False
# audio_1666.wav augmented, False
# audio_1667.wav augmented, True
# audio_1668.wav augmented, False
# audio_1669.wav augmented, True
# audio_167.wav augmented, True
# audio_1670.wav augmented, False
# audio_1671.wav augmented, False
# audio_1672.wav augmented, False
# audio_1673.wav augmented, False
# audio_1674.wav augmented, True
# audio_1675.wav augmented, False
# audio_1676.wav augmented, True
# audio_1677.wav augmented, False
# audio_1678.wav augmented, True
# audio_1679.wav augmented, False
# audio_168.wav augmented, False
# audio_1680.wav augmented, False
# audio_1681.wav augmented, False
# audio_1682.wav augmented, False
# audio_1683.wav augmented, True
# audio_1684.wav augmented, True
# audio_1685.wav augmented, True
# audio_1686.wav augmented, False
# audio_1687.wav augmented, False
# audio_1688.wav augmented, False
# audio_1689.wav augmented, False
# audio_169.wav augmented, True
# audio_1690.wav augmented, False
# audio_1691.wav augmented, True
# audio_1692.wav augmented, True
# audio_1693.wav augmented, True
# audio_1694.wav augmented, False
# audio_1695.wav augmented, True
# audio_1696.wav augmented, False
# audio_1697.wav augmented, True
# audio_1698.wav augmented, True
# audio_1699.wav augmented, True
# audio_17.wav augmented, False
# audio_170.wav augmented, True
# audio_1700.wav augmented, True
# audio_1701.wav augmented, False
# audio_1702.wav augmented, True
# audio_1703.wav augmented, False
# audio_1704.wav augmented, True
# audio_1705.wav augmented, False
# audio_1706.wav augmented, True
# audio_1707.wav augmented, False
# audio_1708.wav augmented, True
# audio_1709.wav augmented, False
# audio_171.wav augmented, True
# audio_1710.wav augmented, True
# audio_1711.wav augmented, False
# audio_1712.wav augmented, False
# audio_1713.wav augmented, False
# audio_1714.wav augmented, True
# audio_1715.wav augmented, False
# audio_1716.wav augmented, True
# audio_1717.wav augmented, True
# audio_1718.wav augmented, False
# audio_1719.wav augmented, True
# audio_172.wav augmented, True
# audio_1720.wav augmented, False
# audio_1721.wav augmented, True
# audio_1722.wav augmented, False
# audio_1723.wav augmented, False
# audio_1724.wav augmented, True
# audio_1725.wav augmented, True
# audio_1726.wav augmented, True
# audio_1727.wav augmented, False
# audio_1728.wav augmented, False
# audio_1729.wav augmented, True
# audio_173.wav augmented, True
# audio_1730.wav augmented, False
# audio_1731.wav augmented, False
# audio_1732.wav augmented, False
# audio_1733.wav augmented, False
# audio_1734.wav augmented, False
# audio_1735.wav augmented, False
# audio_1736.wav augmented, False
# audio_1737.wav augmented, False
# audio_1738.wav augmented, True
# audio_1739.wav augmented, True
# audio_174.wav augmented, False
# audio_1740.wav augmented, True
# audio_1741.wav augmented, True
# audio_1742.wav augmented, False
# audio_1743.wav augmented, True
# audio_1744.wav augmented, False
# audio_1745.wav augmented, False
# audio_1746.wav augmented, True
# audio_1747.wav augmented, True
# audio_1748.wav augmented, True
# audio_1749.wav augmented, False
# audio_175.wav augmented, True
# audio_1750.wav augmented, False
# audio_1751.wav augmented, False
# audio_1752.wav augmented, False
# audio_1753.wav augmented, False
# audio_1754.wav augmented, True
# audio_1755.wav augmented, False
# audio_1756.wav augmented, True
# audio_1757.wav augmented, False
# audio_1758.wav augmented, True
# audio_1759.wav augmented, False
# audio_176.wav augmented, True
# audio_1760.wav augmented, True
# audio_1761.wav augmented, False
# audio_1762.wav augmented, False
# audio_1763.wav augmented, False
# audio_1764.wav augmented, True
# audio_1765.wav augmented, False
# audio_1766.wav augmented, True
# audio_1767.wav augmented, False
# audio_1768.wav augmented, True
# audio_1769.wav augmented, True
# audio_177.wav augmented, True
# audio_1770.wav augmented, True
# audio_1771.wav augmented, False
# audio_1772.wav augmented, False
# audio_1773.wav augmented, True
# audio_1774.wav augmented, True
# audio_1775.wav augmented, False
# audio_1776.wav augmented, False
# audio_1777.wav augmented, True
# audio_1778.wav augmented, True
# audio_1779.wav augmented, False
# audio_178.wav augmented, True
# audio_1780.wav augmented, False
# audio_1781.wav augmented, False
# audio_1782.wav augmented, False
# audio_1783.wav augmented, True
# audio_1784.wav augmented, True
# audio_1785.wav augmented, False
# audio_1786.wav augmented, False
# audio_1787.wav augmented, False
# audio_1788.wav augmented, False
# audio_1789.wav augmented, True
# audio_179.wav augmented, False
# audio_1790.wav augmented, False
# audio_1791.wav augmented, False
# audio_1792.wav augmented, True
# audio_1793.wav augmented, False
# audio_1794.wav augmented, True
# audio_1795.wav augmented, False
# audio_1796.wav augmented, False
# audio_1797.wav augmented, True
# audio_1798.wav augmented, True
# audio_1799.wav augmented, False
# audio_18.wav augmented, True
# audio_180.wav augmented, False
# audio_1800.wav augmented, True
# audio_1801.wav augmented, False
# audio_1802.wav augmented, False
# audio_1803.wav augmented, False
# audio_1804.wav augmented, True
# audio_1805.wav augmented, True
# audio_1806.wav augmented, False
# audio_1807.wav augmented, False
# audio_1808.wav augmented, True
# audio_1809.wav augmented, False
# audio_181.wav augmented, True
# audio_1810.wav augmented, False
# audio_1811.wav augmented, False
# audio_1812.wav augmented, False
# audio_1813.wav augmented, False
# audio_1814.wav augmented, True
# audio_1815.wav augmented, True
# audio_1816.wav augmented, False
# audio_1817.wav augmented, True
# audio_1818.wav augmented, False
# audio_1819.wav augmented, False
# audio_182.wav augmented, False
# audio_1820.wav augmented, False
# audio_1821.wav augmented, True
# audio_1822.wav augmented, False
# audio_1823.wav augmented, False
# audio_1824.wav augmented, True
# audio_1825.wav augmented, False
# audio_1826.wav augmented, False
# audio_1827.wav augmented, True
# audio_1828.wav augmented, False
# audio_1829.wav augmented, True
# audio_183.wav augmented, True
# audio_1830.wav augmented, False
# audio_1831.wav augmented, False
# audio_1832.wav augmented, False
# audio_1833.wav augmented, False
# audio_1834.wav augmented, False
# audio_1835.wav augmented, False
# audio_1836.wav augmented, False
# audio_1837.wav augmented, True
# audio_1838.wav augmented, True
# audio_1839.wav augmented, False
# audio_184.wav augmented, True
# audio_1840.wav augmented, True
# audio_1841.wav augmented, False
# audio_1842.wav augmented, True
# audio_1843.wav augmented, True
# audio_1844.wav augmented, False
# audio_1845.wav augmented, True
# audio_1846.wav augmented, True
# audio_1847.wav augmented, True
# audio_1848.wav augmented, False
# audio_1849.wav augmented, False
# audio_185.wav augmented, True
# audio_1850.wav augmented, True
# audio_1851.wav augmented, True
# audio_1852.wav augmented, False
# audio_1853.wav augmented, False
# audio_1854.wav augmented, False
# audio_1855.wav augmented, True
# audio_1856.wav augmented, True
# audio_1857.wav augmented, True
# audio_1858.wav augmented, True
# audio_1859.wav augmented, False
# audio_186.wav augmented, True
# audio_1860.wav augmented, True
# audio_1861.wav augmented, False
# audio_1862.wav augmented, True
# audio_1863.wav augmented, False
# audio_1864.wav augmented, True
# audio_1865.wav augmented, True
# audio_1866.wav augmented, False
# audio_1867.wav augmented, True
# audio_1868.wav augmented, True
# audio_1869.wav augmented, False
# audio_187.wav augmented, True
# audio_1870.wav augmented, False
# audio_1871.wav augmented, False
# audio_1872.wav augmented, False
# audio_1873.wav augmented, False
# audio_1874.wav augmented, True
# audio_1875.wav augmented, False
# audio_1876.wav augmented, True
# audio_1877.wav augmented, True
# audio_1878.wav augmented, True
# audio_1879.wav augmented, False
# audio_188.wav augmented, False
# audio_1880.wav augmented, False
# audio_1881.wav augmented, True
# audio_1882.wav augmented, False
# audio_1883.wav augmented, True
# audio_1884.wav augmented, False
# audio_1885.wav augmented, True
# audio_1886.wav augmented, True
# audio_1887.wav augmented, False
# audio_1888.wav augmented, True
# audio_1889.wav augmented, False
# audio_189.wav augmented, False
# audio_1890.wav augmented, False
# audio_1891.wav augmented, False
# audio_1892.wav augmented, True
# audio_1893.wav augmented, False
# audio_1894.wav augmented, True
# audio_1895.wav augmented, True
# audio_1896.wav augmented, False
# audio_1897.wav augmented, False
# audio_1898.wav augmented, False
# audio_1899.wav augmented, True
# audio_19.wav augmented, False
# audio_190.wav augmented, False
# audio_1900.wav augmented, True
# audio_1901.wav augmented, False
# audio_1902.wav augmented, False
# audio_1903.wav augmented, False
# audio_1904.wav augmented, False
# audio_1905.wav augmented, False
# audio_1906.wav augmented, False
# audio_1907.wav augmented, True
# audio_1908.wav augmented, True
# audio_1909.wav augmented, True
# audio_191.wav augmented, True
# audio_1910.wav augmented, False
# audio_1911.wav augmented, False
# audio_1912.wav augmented, True
# audio_1913.wav augmented, True
# audio_1914.wav augmented, False
# audio_1915.wav augmented, False
# audio_1916.wav augmented, True
# audio_1917.wav augmented, False
# audio_1918.wav augmented, False
# audio_1919.wav augmented, False
# audio_192.wav augmented, False
# audio_1920.wav augmented, False
# audio_1921.wav augmented, True
# audio_1922.wav augmented, True
# audio_1923.wav augmented, True
# audio_1924.wav augmented, True
# audio_1925.wav augmented, True
# audio_1926.wav augmented, False
# audio_1927.wav augmented, False
# audio_1928.wav augmented, False
# audio_1929.wav augmented, False
# audio_193.wav augmented, False
# audio_1930.wav augmented, True
# audio_1931.wav augmented, False
# audio_1932.wav augmented, False
# audio_1933.wav augmented, False
# audio_1934.wav augmented, False
# audio_1935.wav augmented, True
# audio_1936.wav augmented, True
# audio_1937.wav augmented, True
# audio_1938.wav augmented, False
# audio_1939.wav augmented, False
# audio_194.wav augmented, False
# audio_1940.wav augmented, False
# audio_1941.wav augmented, False
# audio_1942.wav augmented, False
# audio_1943.wav augmented, False
# audio_1944.wav augmented, True
# audio_1945.wav augmented, True
# audio_1946.wav augmented, True
# audio_1947.wav augmented, True
# audio_1948.wav augmented, False
# audio_1949.wav augmented, True
# audio_195.wav augmented, False
# audio_1950.wav augmented, False
# audio_1951.wav augmented, True
# audio_1952.wav augmented, True
# audio_1953.wav augmented, False
# audio_1954.wav augmented, False
# audio_1955.wav augmented, False
# audio_1956.wav augmented, False
# audio_1957.wav augmented, False
# audio_1958.wav augmented, True
# audio_1959.wav augmented, False
# audio_196.wav augmented, False
# audio_1960.wav augmented, False
# audio_1961.wav augmented, True
# audio_1962.wav augmented, True
# audio_1963.wav augmented, True
# audio_1964.wav augmented, False
# audio_1965.wav augmented, False
# audio_1966.wav augmented, False
# audio_1967.wav augmented, True
# audio_1968.wav augmented, False
# audio_1969.wav augmented, False
# audio_197.wav augmented, True
# audio_1970.wav augmented, True
# audio_1971.wav augmented, False
# audio_1972.wav augmented, False
# audio_1973.wav augmented, False
# audio_1974.wav augmented, False
# audio_1975.wav augmented, False
# audio_1976.wav augmented, False
# audio_1977.wav augmented, False
# audio_1978.wav augmented, False
# audio_1979.wav augmented, True
# audio_198.wav augmented, False
# audio_1980.wav augmented, False
# audio_1981.wav augmented, True
# audio_1982.wav augmented, True
# audio_1983.wav augmented, True
# audio_1984.wav augmented, True
# audio_1985.wav augmented, False
# audio_1986.wav augmented, True
# audio_1987.wav augmented, False
# audio_1988.wav augmented, False
# audio_1989.wav augmented, True
# audio_199.wav augmented, False
# audio_1990.wav augmented, True
# audio_1991.wav augmented, True
# audio_1992.wav augmented, True
# audio_1993.wav augmented, False
# audio_1994.wav augmented, True
# audio_1995.wav augmented, True
# audio_1996.wav augmented, True
# audio_1997.wav augmented, True
# audio_1998.wav augmented, True
# audio_1999.wav augmented, False
# audio_2.wav augmented, False
# audio_20.wav augmented, False
# audio_200.wav augmented, True
# audio_2000.wav augmented, True
# audio_2001.wav augmented, False
# audio_2002.wav augmented, False
# audio_2003.wav augmented, False
# audio_2004.wav augmented, False
# audio_2005.wav augmented, False
# audio_2006.wav augmented, True
# audio_2007.wav augmented, True
# audio_2008.wav augmented, False
# audio_2009.wav augmented, False
# audio_201.wav augmented, False
# audio_2010.wav augmented, False
# audio_2011.wav augmented, False
# audio_2012.wav augmented, True
# audio_2013.wav augmented, True
# audio_2014.wav augmented, True
# audio_2015.wav augmented, True
# audio_2016.wav augmented, True
# audio_2017.wav augmented, True
# audio_2018.wav augmented, False
# audio_2019.wav augmented, False
# audio_202.wav augmented, True
# audio_2020.wav augmented, False
# audio_2021.wav augmented, False
# audio_2022.wav augmented, True
# audio_2023.wav augmented, True
# audio_2024.wav augmented, False
# audio_2025.wav augmented, True
# audio_2026.wav augmented, False
# audio_2027.wav augmented, False
# audio_2028.wav augmented, False
# audio_2029.wav augmented, False
# audio_203.wav augmented, True
# audio_2030.wav augmented, False
# audio_2031.wav augmented, True
# audio_2032.wav augmented, False
# audio_2033.wav augmented, False
# audio_2034.wav augmented, True
# audio_2035.wav augmented, False
# audio_2036.wav augmented, False
# audio_2037.wav augmented, False
# audio_2038.wav augmented, True
# audio_2039.wav augmented, True
# audio_204.wav augmented, True
# audio_2040.wav augmented, False
# audio_2041.wav augmented, True
# audio_2042.wav augmented, True
# audio_2043.wav augmented, False
# audio_2044.wav augmented, True
# audio_2045.wav augmented, False
# audio_2046.wav augmented, False
# audio_2047.wav augmented, False
# audio_2048.wav augmented, True
# audio_2049.wav augmented, True
# audio_205.wav augmented, False
# audio_2050.wav augmented, True
# audio_2051.wav augmented, False
# audio_2052.wav augmented, True
# audio_2053.wav augmented, True
# audio_2054.wav augmented, False
# audio_2055.wav augmented, True
# audio_2056.wav augmented, True
# audio_2057.wav augmented, False
# audio_2058.wav augmented, False
# audio_2059.wav augmented, True
# audio_206.wav augmented, False
# audio_2060.wav augmented, True
# audio_2061.wav augmented, True
# audio_2062.wav augmented, True
# audio_2063.wav augmented, False
# audio_2064.wav augmented, True
# audio_2065.wav augmented, False
# audio_2066.wav augmented, False
# audio_2067.wav augmented, True
# audio_2068.wav augmented, True
# audio_2069.wav augmented, False
# audio_207.wav augmented, False
# audio_2070.wav augmented, False
# audio_2071.wav augmented, True
# audio_2072.wav augmented, False
# audio_2073.wav augmented, True
# audio_2074.wav augmented, True
# audio_2075.wav augmented, False
# audio_2076.wav augmented, False
# audio_2077.wav augmented, False
# audio_2078.wav augmented, True
# audio_2079.wav augmented, True
# audio_208.wav augmented, False
# audio_2080.wav augmented, True
# audio_2081.wav augmented, True
# audio_2082.wav augmented, True
# audio_2083.wav augmented, True
# audio_2084.wav augmented, True
# audio_2085.wav augmented, True
# audio_2086.wav augmented, False
# audio_2087.wav augmented, False
# audio_2088.wav augmented, True
# audio_2089.wav augmented, True
# audio_209.wav augmented, True
# audio_2090.wav augmented, True
# audio_2091.wav augmented, False
# audio_2092.wav augmented, True
# audio_2093.wav augmented, True
# audio_2094.wav augmented, True
# audio_2095.wav augmented, False
# audio_2096.wav augmented, False
# audio_2097.wav augmented, True
# audio_2098.wav augmented, True
# audio_2099.wav augmented, False
# audio_21.wav augmented, False
# audio_210.wav augmented, False
# audio_2100.wav augmented, True
# audio_2101.wav augmented, True
# audio_2102.wav augmented, False
# audio_2103.wav augmented, True
# audio_2104.wav augmented, True
# audio_2105.wav augmented, True
# audio_2106.wav augmented, True
# audio_2107.wav augmented, False
# audio_2108.wav augmented, False
# audio_2109.wav augmented, True
# audio_211.wav augmented, False
# audio_2110.wav augmented, True
# audio_2111.wav augmented, True
# audio_2112.wav augmented, False
# audio_2113.wav augmented, False
# audio_2114.wav augmented, False
# audio_2115.wav augmented, True
# audio_2116.wav augmented, False
# audio_2117.wav augmented, True
# audio_2118.wav augmented, False
# audio_2119.wav augmented, True
# audio_212.wav augmented, True
# audio_2120.wav augmented, True
# audio_2121.wav augmented, False
# audio_2122.wav augmented, True
# audio_2123.wav augmented, True
# audio_2124.wav augmented, True
# audio_2125.wav augmented, True
# audio_2126.wav augmented, False
# audio_2127.wav augmented, True
# audio_2128.wav augmented, True
# audio_2129.wav augmented, False
# audio_213.wav augmented, True
# audio_2130.wav augmented, False
# audio_2131.wav augmented, True
# audio_2132.wav augmented, True
# audio_2133.wav augmented, False
# audio_2134.wav augmented, True
# audio_2135.wav augmented, False
# audio_2136.wav augmented, True
# audio_2137.wav augmented, True
# audio_2138.wav augmented, True
# audio_2139.wav augmented, True
# audio_214.wav augmented, False
# audio_2140.wav augmented, True
# audio_2141.wav augmented, True
# audio_2142.wav augmented, True
# audio_2143.wav augmented, False
# audio_2144.wav augmented, False
# audio_2145.wav augmented, False
# audio_2146.wav augmented, True
# audio_2147.wav augmented, True
# audio_2148.wav augmented, True
# audio_2149.wav augmented, False
# audio_215.wav augmented, True
# audio_2150.wav augmented, True
# audio_2151.wav augmented, False
# audio_2152.wav augmented, True
# audio_2153.wav augmented, False
# audio_2154.wav augmented, True
# audio_2155.wav augmented, False
# audio_2156.wav augmented, True
# audio_2157.wav augmented, False
# audio_2158.wav augmented, True
# audio_2159.wav augmented, False
# audio_216.wav augmented, True
# audio_2160.wav augmented, False
# audio_2161.wav augmented, False
# audio_2162.wav augmented, False
# audio_2163.wav augmented, False
# audio_2164.wav augmented, False
# audio_2165.wav augmented, False
# audio_2166.wav augmented, True
# audio_2167.wav augmented, True
# audio_2168.wav augmented, True
# audio_2169.wav augmented, True
# audio_217.wav augmented, False
# audio_2170.wav augmented, True
# audio_2171.wav augmented, True
# audio_2172.wav augmented, False
# audio_2173.wav augmented, True
# audio_2174.wav augmented, True
# audio_2175.wav augmented, False
# audio_2176.wav augmented, True
# audio_2177.wav augmented, False
# audio_2178.wav augmented, False
# audio_2179.wav augmented, True
# audio_218.wav augmented, False
# audio_2180.wav augmented, True
# audio_2181.wav augmented, False
# audio_2182.wav augmented, False
# audio_2183.wav augmented, False
# audio_2184.wav augmented, False
# audio_2185.wav augmented, False
# audio_2186.wav augmented, False
# audio_2187.wav augmented, False
# audio_2188.wav augmented, True
# audio_2189.wav augmented, False
# audio_219.wav augmented, False
# audio_2190.wav augmented, False
# audio_2191.wav augmented, False
# audio_2192.wav augmented, False
# audio_2193.wav augmented, True
# audio_2194.wav augmented, True
# audio_2195.wav augmented, False
# audio_2196.wav augmented, True
# audio_2197.wav augmented, False
# audio_2198.wav augmented, True
# audio_2199.wav augmented, True
# audio_22.wav augmented, False
# audio_220.wav augmented, False
# audio_2200.wav augmented, True
# audio_2201.wav augmented, False
# audio_2202.wav augmented, False
# audio_2203.wav augmented, True
# audio_2204.wav augmented, True
# audio_2205.wav augmented, False
# audio_2206.wav augmented, True
# audio_2207.wav augmented, True
# audio_2208.wav augmented, True
# audio_2209.wav augmented, True
# audio_221.wav augmented, False
# audio_2210.wav augmented, True
# audio_2211.wav augmented, True
# audio_2212.wav augmented, False
# audio_2213.wav augmented, False
# audio_2214.wav augmented, True
# audio_2215.wav augmented, False
# audio_2216.wav augmented, False
# audio_2217.wav augmented, True
# audio_2218.wav augmented, False
# audio_2219.wav augmented, False
# audio_222.wav augmented, True
# audio_2220.wav augmented, True
# audio_2221.wav augmented, False
# audio_2222.wav augmented, True
# audio_2223.wav augmented, False
# audio_2224.wav augmented, True
# audio_2225.wav augmented, True
# audio_2226.wav augmented, True
# audio_2227.wav augmented, True
# audio_2228.wav augmented, False
# audio_2229.wav augmented, True
# audio_223.wav augmented, False
# audio_2230.wav augmented, True
# audio_2231.wav augmented, False
# audio_2232.wav augmented, True
# audio_2233.wav augmented, False
# audio_2234.wav augmented, False
# audio_2235.wav augmented, False
# audio_2236.wav augmented, True
# audio_2237.wav augmented, True
# audio_2238.wav augmented, False
# audio_2239.wav augmented, False
# audio_224.wav augmented, True
# audio_2240.wav augmented, False
# audio_2241.wav augmented, True
# audio_2242.wav augmented, False
# audio_2243.wav augmented, False
# audio_2244.wav augmented, False
# audio_2245.wav augmented, False
# audio_2246.wav augmented, True
# audio_2247.wav augmented, True
# audio_2248.wav augmented, False
# audio_2249.wav augmented, False
# audio_225.wav augmented, False
# audio_2250.wav augmented, True
# audio_2251.wav augmented, True
# audio_2252.wav augmented, False
# audio_2253.wav augmented, True
# audio_2254.wav augmented, False
# audio_2255.wav augmented, False
# audio_2256.wav augmented, False
# audio_2257.wav augmented, False
# audio_2258.wav augmented, False
# audio_2259.wav augmented, False
# audio_226.wav augmented, False
# audio_2260.wav augmented, True
# audio_2261.wav augmented, False
# audio_2262.wav augmented, True
# audio_2263.wav augmented, True
# audio_2264.wav augmented, False
# audio_2265.wav augmented, True
# audio_2266.wav augmented, False
# audio_2267.wav augmented, True
# audio_2268.wav augmented, True
# audio_2269.wav augmented, False
# audio_227.wav augmented, True
# audio_2270.wav augmented, True
# audio_2271.wav augmented, True
# audio_2272.wav augmented, False
# audio_2273.wav augmented, True
# audio_2274.wav augmented, False
# audio_2275.wav augmented, True
# audio_2276.wav augmented, True
# audio_2277.wav augmented, False
# audio_2278.wav augmented, False
# audio_2279.wav augmented, False
# audio_228.wav augmented, False
# audio_2280.wav augmented, False
# audio_2281.wav augmented, True
# audio_2282.wav augmented, True
# audio_2283.wav augmented, True
# audio_2284.wav augmented, True
# audio_2285.wav augmented, False
# audio_2286.wav augmented, True
# audio_2287.wav augmented, False
# audio_2288.wav augmented, True
# audio_2289.wav augmented, False
# audio_229.wav augmented, False
# audio_2290.wav augmented, False
# audio_2291.wav augmented, True
# audio_2292.wav augmented, False
# audio_2293.wav augmented, True
# audio_2294.wav augmented, False
# audio_2295.wav augmented, False
# audio_2296.wav augmented, True
# audio_2297.wav augmented, True
# audio_2298.wav augmented, False
# audio_2299.wav augmented, True
# audio_23.wav augmented, False
# audio_230.wav augmented, True
# audio_2300.wav augmented, False
# audio_2301.wav augmented, False
# audio_2302.wav augmented, False
# audio_2303.wav augmented, True
# audio_2304.wav augmented, True
# audio_2305.wav augmented, True
# audio_2306.wav augmented, True
# audio_2307.wav augmented, False
# audio_2308.wav augmented, True
# audio_2309.wav augmented, True
# audio_231.wav augmented, False
# audio_2310.wav augmented, False
# audio_2311.wav augmented, True
# audio_2312.wav augmented, True
# audio_2313.wav augmented, True
# audio_2314.wav augmented, False
# audio_2315.wav augmented, False
# audio_2316.wav augmented, True
# audio_2317.wav augmented, True
# audio_2318.wav augmented, True
# audio_2319.wav augmented, True
# audio_232.wav augmented, True
# audio_2320.wav augmented, True
# audio_2321.wav augmented, False
# audio_2322.wav augmented, False
# audio_2323.wav augmented, False
# audio_2324.wav augmented, True
# audio_2325.wav augmented, False
# audio_2326.wav augmented, True
# audio_2327.wav augmented, True
# audio_2328.wav augmented, False
# audio_2329.wav augmented, False
# audio_233.wav augmented, False
# audio_2330.wav augmented, True
# audio_2331.wav augmented, True
# audio_2332.wav augmented, True
# audio_2333.wav augmented, False
# audio_2334.wav augmented, True
# audio_2335.wav augmented, True
# audio_2336.wav augmented, False
# audio_2337.wav augmented, False
# audio_2338.wav augmented, False
# audio_2339.wav augmented, False
# audio_234.wav augmented, True
# audio_2340.wav augmented, False
# audio_2341.wav augmented, True
# audio_2342.wav augmented, False
# audio_2343.wav augmented, False
# audio_2344.wav augmented, True
# audio_2345.wav augmented, True
# audio_2346.wav augmented, False
# audio_2347.wav augmented, True
# audio_2348.wav augmented, True
# audio_2349.wav augmented, True
# audio_235.wav augmented, False
# audio_2350.wav augmented, True
# audio_2351.wav augmented, True
# audio_2352.wav augmented, False
# audio_2353.wav augmented, False
# audio_2354.wav augmented, True
# audio_2355.wav augmented, False
# audio_2356.wav augmented, True
# audio_2357.wav augmented, True
# audio_2358.wav augmented, True
# audio_2359.wav augmented, True
# audio_236.wav augmented, False
# audio_2360.wav augmented, False
# audio_2361.wav augmented, True
# audio_2362.wav augmented, True
# audio_2363.wav augmented, True
# audio_2364.wav augmented, False
# audio_2365.wav augmented, True
# audio_2366.wav augmented, False
# audio_2367.wav augmented, True
# audio_2368.wav augmented, True
# audio_2369.wav augmented, True
# audio_237.wav augmented, True
# audio_2370.wav augmented, True
# audio_2371.wav augmented, False
# audio_2372.wav augmented, False
# audio_2373.wav augmented, False
# ...
# audio_528.wav augmented, False
# audio_529.wav augmented, True
# audio_53.wav augmented, False
# audio_530.wav augmented, True
# audio_531.wav augmented, True
# audio_532.wav augmented, False
# audio_533.wav augmented, False
# audio_534.wav augmented, False
# audio_535.wav augmented, False
# audio_536.wav augmented, False
# audio_537.wav augmented, True
# audio_538.wav augmented, False
# audio_539.wav augmented, True
# audio_54.wav augmented, False
# audio_540.wav augmented, False
# audio_541.wav augmented, False
# audio_542.wav augmented, False
# audio_543.wav augmented, False
# audio_544.wav augmented, False
# audio_545.wav augmented, False
# audio_546.wav augmented, True
# audio_547.wav augmented, True
# audio_548.wav augmented, False
# audio_549.wav augmented, True
# audio_55.wav augmented, False
# audio_550.wav augmented, False
# audio_551.wav augmented, False
# audio_552.wav augmented, True
# audio_553.wav augmented, True
# audio_554.wav augmented, True
# audio_555.wav augmented, True
# audio_556.wav augmented, False
# audio_557.wav augmented, False
# audio_558.wav augmented, True
# audio_559.wav augmented, True
# audio_56.wav augmented, True
# audio_560.wav augmented, True
# audio_561.wav augmented, False
# audio_562.wav augmented, True
# audio_563.wav augmented, False
# audio_564.wav augmented, False
# audio_565.wav augmented, True
# audio_566.wav augmented, True
# audio_567.wav augmented, False
# audio_568.wav augmented, False
# audio_569.wav augmented, False
# audio_57.wav augmented, False
# audio_570.wav augmented, False
# audio_571.wav augmented, False
# audio_572.wav augmented, False
# audio_573.wav augmented, False
# audio_574.wav augmented, False
# audio_575.wav augmented, False
# audio_576.wav augmented, False
# audio_577.wav augmented, False
# audio_578.wav augmented, False
# audio_579.wav augmented, True
# audio_58.wav augmented, False
# audio_580.wav augmented, False
# audio_581.wav augmented, True
# audio_582.wav augmented, True
# audio_583.wav augmented, True
# audio_584.wav augmented, False
# audio_585.wav augmented, True
# audio_586.wav augmented, True
# audio_587.wav augmented, False
# audio_588.wav augmented, True
# audio_589.wav augmented, True
# audio_59.wav augmented, False
# audio_590.wav augmented, False
# audio_591.wav augmented, False
# audio_592.wav augmented, True
# audio_593.wav augmented, False
# audio_594.wav augmented, False
# audio_595.wav augmented, True
# audio_596.wav augmented, True
# audio_597.wav augmented, True
# audio_598.wav augmented, True
# audio_599.wav augmented, False
# audio_6.wav augmented, True
# audio_60.wav augmented, True
# audio_600.wav augmented, False
# audio_601.wav augmented, True
# audio_602.wav augmented, False
# audio_603.wav augmented, True
# audio_604.wav augmented, True
# audio_605.wav augmented, False
# audio_606.wav augmented, True
# audio_607.wav augmented, True
# audio_608.wav augmented, False
# audio_609.wav augmented, True
# audio_61.wav augmented, False
# audio_610.wav augmented, False
# audio_611.wav augmented, False
# audio_612.wav augmented, True
# audio_613.wav augmented, True
# audio_614.wav augmented, False
# audio_615.wav augmented, False
# audio_616.wav augmented, False
# audio_617.wav augmented, True
# audio_618.wav augmented, False
# audio_619.wav augmented, True
# audio_62.wav augmented, False
# audio_620.wav augmented, False
# audio_621.wav augmented, True
# audio_622.wav augmented, False
# audio_623.wav augmented, False
# audio_624.wav augmented, False
# audio_625.wav augmented, True
# audio_626.wav augmented, False
# audio_627.wav augmented, False
# audio_628.wav augmented, False
# audio_629.wav augmented, True
# audio_63.wav augmented, True
# audio_630.wav augmented, False
# audio_631.wav augmented, False
# audio_632.wav augmented, True
# audio_633.wav augmented, False
# audio_634.wav augmented, True
# audio_635.wav augmented, False
# audio_636.wav augmented, True
# audio_637.wav augmented, False
# audio_638.wav augmented, False
# audio_639.wav augmented, False
# audio_64.wav augmented, True
# audio_640.wav augmented, False
# audio_641.wav augmented, False
# audio_642.wav augmented, False
# audio_643.wav augmented, False
# audio_644.wav augmented, False
# audio_645.wav augmented, False
# audio_646.wav augmented, True
# audio_647.wav augmented, True
# audio_648.wav augmented, True
# audio_649.wav augmented, True
# audio_65.wav augmented, False
# audio_650.wav augmented, False
# audio_651.wav augmented, True
# audio_652.wav augmented, True
# audio_653.wav augmented, False
# audio_654.wav augmented, False
# audio_655.wav augmented, True
# audio_656.wav augmented, False
# audio_657.wav augmented, False
# audio_658.wav augmented, False
# audio_659.wav augmented, False
# audio_66.wav augmented, False
# audio_660.wav augmented, False
# audio_661.wav augmented, False
# audio_662.wav augmented, True
# audio_663.wav augmented, False
# audio_664.wav augmented, True
# audio_665.wav augmented, True
# audio_666.wav augmented, False
# audio_667.wav augmented, True
# audio_668.wav augmented, True
# audio_669.wav augmented, False
# audio_67.wav augmented, True
# audio_670.wav augmented, True
# audio_671.wav augmented, False
# audio_672.wav augmented, True
# audio_673.wav augmented, False
# audio_674.wav augmented, True
# audio_675.wav augmented, False
# audio_676.wav augmented, False
# audio_677.wav augmented, True
# audio_678.wav augmented, True
# audio_679.wav augmented, False
# audio_68.wav augmented, True
# audio_680.wav augmented, True
# audio_681.wav augmented, False
# audio_682.wav augmented, False
# audio_683.wav augmented, True
# audio_684.wav augmented, True
# audio_685.wav augmented, True
# audio_686.wav augmented, True
# audio_687.wav augmented, True
# audio_688.wav augmented, True
# audio_689.wav augmented, True
# audio_69.wav augmented, True
# audio_690.wav augmented, False
# audio_691.wav augmented, False
# audio_692.wav augmented, False
# audio_693.wav augmented, False
# audio_694.wav augmented, True
# audio_695.wav augmented, True
# audio_696.wav augmented, True
# audio_697.wav augmented, False
# audio_698.wav augmented, False
# audio_699.wav augmented, False
# audio_7.wav augmented, False
# audio_70.wav augmented, True
# audio_700.wav augmented, False
# audio_701.wav augmented, True
# audio_702.wav augmented, False
# audio_703.wav augmented, True
# audio_704.wav augmented, True
# audio_705.wav augmented, True
# audio_706.wav augmented, True
# audio_707.wav augmented, True
# audio_708.wav augmented, True
# audio_709.wav augmented, True
# audio_71.wav augmented, True
# audio_710.wav augmented, False
# audio_711.wav augmented, True
# audio_712.wav augmented, False
# audio_713.wav augmented, True
# audio_714.wav augmented, False
# audio_715.wav augmented, False
# audio_716.wav augmented, True
# audio_717.wav augmented, False
# audio_718.wav augmented, True
# audio_719.wav augmented, True
# audio_72.wav augmented, False
# audio_720.wav augmented, False
# audio_721.wav augmented, False
# audio_722.wav augmented, True
# audio_723.wav augmented, False
# audio_724.wav augmented, False
# audio_725.wav augmented, True
# audio_726.wav augmented, False
# audio_727.wav augmented, False
# audio_728.wav augmented, True
# audio_729.wav augmented, True
# audio_73.wav augmented, True
# audio_730.wav augmented, True
# audio_731.wav augmented, False
# audio_732.wav augmented, True
# audio_733.wav augmented, True
# audio_734.wav augmented, False
# audio_735.wav augmented, True
# audio_736.wav augmented, False
# audio_737.wav augmented, False
# audio_738.wav augmented, False
# audio_739.wav augmented, False
# audio_74.wav augmented, False
# audio_740.wav augmented, False
# audio_741.wav augmented, True
# audio_742.wav augmented, True
# audio_743.wav augmented, False
# audio_744.wav augmented, False
# audio_745.wav augmented, False
# audio_746.wav augmented, False
# audio_747.wav augmented, True
# audio_748.wav augmented, False
# audio_749.wav augmented, True
# audio_75.wav augmented, True
# audio_750.wav augmented, False
# audio_751.wav augmented, False
# audio_752.wav augmented, False
# audio_753.wav augmented, False
# audio_754.wav augmented, True
# audio_755.wav augmented, True
# audio_756.wav augmented, True
# audio_757.wav augmented, True
# audio_758.wav augmented, False
# audio_759.wav augmented, False
# audio_76.wav augmented, True
# audio_760.wav augmented, False
# audio_761.wav augmented, True
# audio_762.wav augmented, False
# audio_763.wav augmented, True
# audio_764.wav augmented, True
# audio_765.wav augmented, False
# audio_766.wav augmented, True
# audio_767.wav augmented, False
# audio_768.wav augmented, True
# audio_769.wav augmented, True
# audio_77.wav augmented, True
# audio_770.wav augmented, False
# audio_771.wav augmented, False
# audio_772.wav augmented, False
# audio_773.wav augmented, False
# audio_774.wav augmented, False
# audio_775.wav augmented, True
# audio_776.wav augmented, False
# audio_777.wav augmented, False
# audio_778.wav augmented, True
# audio_779.wav augmented, True
# audio_78.wav augmented, False
# audio_780.wav augmented, False
# audio_781.wav augmented, True
# audio_782.wav augmented, True
# audio_783.wav augmented, False
# audio_784.wav augmented, True
# audio_785.wav augmented, True
# audio_786.wav augmented, False
# audio_787.wav augmented, True
# audio_788.wav augmented, True
# audio_789.wav augmented, False
# audio_79.wav augmented, True
# audio_790.wav augmented, True
# audio_791.wav augmented, False
# audio_792.wav augmented, True
# audio_793.wav augmented, True
# audio_794.wav augmented, False
# audio_795.wav augmented, True
# audio_796.wav augmented, False
# audio_797.wav augmented, False
# audio_798.wav augmented, True
# audio_799.wav augmented, False
# audio_8.wav augmented, True
# audio_80.wav augmented, True
# audio_800.wav augmented, True
# audio_801.wav augmented, False
# audio_802.wav augmented, False
# audio_803.wav augmented, False
# audio_804.wav augmented, True
# audio_805.wav augmented, True
# audio_806.wav augmented, True
# audio_807.wav augmented, False
# audio_808.wav augmented, False
# audio_809.wav augmented, False
# audio_81.wav augmented, True
# audio_810.wav augmented, False
# audio_811.wav augmented, False
# audio_812.wav augmented, True
# audio_813.wav augmented, True
# audio_814.wav augmented, False
# audio_815.wav augmented, False
# audio_816.wav augmented, True
# audio_817.wav augmented, True
# audio_818.wav augmented, False
# audio_819.wav augmented, True
# audio_82.wav augmented, True
# audio_820.wav augmented, True
# audio_821.wav augmented, False
# audio_822.wav augmented, True
# audio_823.wav augmented, False
# audio_824.wav augmented, False
# audio_825.wav augmented, True
# audio_826.wav augmented, False
# audio_827.wav augmented, True
# audio_828.wav augmented, False
# audio_829.wav augmented, False
# audio_83.wav augmented, False
# audio_830.wav augmented, True
# audio_831.wav augmented, False
# audio_832.wav augmented, False
# audio_833.wav augmented, True
# audio_834.wav augmented, False
# audio_835.wav augmented, False
# audio_836.wav augmented, False
# audio_837.wav augmented, False
# audio_838.wav augmented, False
# audio_839.wav augmented, True
# audio_84.wav augmented, False
# audio_840.wav augmented, True
# audio_841.wav augmented, False
# audio_842.wav augmented, True
# audio_843.wav augmented, True
# audio_844.wav augmented, True
# audio_845.wav augmented, True
# audio_846.wav augmented, False
# audio_847.wav augmented, True
# audio_848.wav augmented, True
# audio_849.wav augmented, True
# audio_85.wav augmented, True
# audio_850.wav augmented, False
# audio_851.wav augmented, True
# audio_852.wav augmented, False
# audio_853.wav augmented, True
# audio_854.wav augmented, False
# audio_855.wav augmented, True
# audio_856.wav augmented, True
# audio_857.wav augmented, False
# audio_858.wav augmented, True
# audio_859.wav augmented, False
# audio_86.wav augmented, False
# audio_860.wav augmented, False
# audio_861.wav augmented, False
# audio_862.wav augmented, True
# audio_863.wav augmented, False
# audio_864.wav augmented, True
# audio_865.wav augmented, True
# audio_866.wav augmented, True
# audio_867.wav augmented, True
# audio_868.wav augmented, False
# audio_869.wav augmented, False
# audio_87.wav augmented, True
# audio_870.wav augmented, False
# audio_871.wav augmented, False
# audio_872.wav augmented, True
# audio_873.wav augmented, False
# audio_874.wav augmented, False
# audio_875.wav augmented, True
# audio_876.wav augmented, True
# audio_877.wav augmented, False
# audio_878.wav augmented, True
# audio_879.wav augmented, True
# audio_88.wav augmented, False
# audio_880.wav augmented, True
# audio_881.wav augmented, True
# audio_882.wav augmented, True
# audio_883.wav augmented, False
# audio_884.wav augmented, False
# audio_885.wav augmented, True
# audio_886.wav augmented, False
# audio_887.wav augmented, True
# audio_888.wav augmented, False
# audio_889.wav augmented, False
# audio_89.wav augmented, False
# audio_890.wav augmented, True
# audio_891.wav augmented, False
# audio_892.wav augmented, False
# audio_893.wav augmented, False
# audio_894.wav augmented, False
# audio_895.wav augmented, True
# audio_896.wav augmented, True
# audio_897.wav augmented, False
# audio_898.wav augmented, False
# audio_899.wav augmented, False
# audio_9.wav augmented, True
# audio_90.wav augmented, False
# audio_900.wav augmented, True
# audio_901.wav augmented, False
# audio_902.wav augmented, False
# audio_903.wav augmented, True
# audio_904.wav augmented, True
# audio_905.wav augmented, True
# audio_906.wav augmented, True
# audio_907.wav augmented, False
# audio_908.wav augmented, True
# audio_909.wav augmented, False
# audio_91.wav augmented, True
# audio_910.wav augmented, True
# audio_911.wav augmented, False
# audio_912.wav augmented, False
# audio_913.wav augmented, False
# audio_914.wav augmented, False
# audio_915.wav augmented, True
# audio_916.wav augmented, True
# audio_917.wav augmented, False
# audio_918.wav augmented, True
# audio_919.wav augmented, True
# audio_92.wav augmented, False
# audio_920.wav augmented, False
# audio_921.wav augmented, False
# audio_922.wav augmented, False
# audio_923.wav augmented, True
# audio_924.wav augmented, False
# audio_925.wav augmented, True
# audio_926.wav augmented, True
# audio_927.wav augmented, True
# audio_928.wav augmented, False
# audio_929.wav augmented, True
# audio_93.wav augmented, False
# audio_930.wav augmented, False
# audio_931.wav augmented, False
# audio_932.wav augmented, True
# audio_933.wav augmented, True
# audio_934.wav augmented, True
# audio_935.wav augmented, True
# audio_936.wav augmented, True
# audio_937.wav augmented, False
# audio_938.wav augmented, False
# audio_939.wav augmented, True
# audio_94.wav augmented, False
# audio_940.wav augmented, False
# audio_941.wav augmented, True
# audio_942.wav augmented, True
# audio_943.wav augmented, True
# audio_944.wav augmented, False
# audio_945.wav augmented, True
# audio_946.wav augmented, True
# audio_947.wav augmented, True
# audio_948.wav augmented, False
# audio_949.wav augmented, True
# audio_95.wav augmented, False
# audio_950.wav augmented, False
# audio_951.wav augmented, False
# audio_952.wav augmented, True
# audio_953.wav augmented, True
# audio_954.wav augmented, False
# audio_955.wav augmented, False
# audio_956.wav augmented, True
# audio_957.wav augmented, True
# audio_958.wav augmented, True
# audio_959.wav augmented, True
# audio_96.wav augmented, True
# audio_960.wav augmented, True
# audio_961.wav augmented, False
# audio_962.wav augmented, False
# audio_963.wav augmented, True
# audio_964.wav augmented, False
# audio_965.wav augmented, True
# audio_966.wav augmented, True
# audio_967.wav augmented, False
# audio_968.wav augmented, False
# audio_969.wav augmented, True
# audio_97.wav augmented, True
# audio_970.wav augmented, False
# audio_971.wav augmented, False
# audio_972.wav augmented, True
# audio_973.wav augmented, True
# audio_974.wav augmented, True
# audio_975.wav augmented, True
# audio_976.wav augmented, True
# audio_977.wav augmented, True
# audio_978.wav augmented, True
# audio_979.wav augmented, True
# audio_98.wav augmented, True
# audio_980.wav augmented, False
# audio_981.wav augmented, True
# audio_982.wav augmented, False
# audio_983.wav augmented, True
# audio_984.wav augmented, False
# audio_985.wav augmented, False
# audio_986.wav augmented, False
# audio_987.wav augmented, True
# audio_988.wav augmented, True
# audio_989.wav augmented, True
# audio_99.wav augmented, False
# audio_990.wav augmented, False
# audio_991.wav augmented, False
# audio_992.wav augmented, True
# audio_993.wav augmented, True
# audio_994.wav augmented, False
# audio_995.wav augmented, False
# audio_996.wav augmented, False
# audio_997.wav augmented, False
# audio_998.wav augmented, False
# audio_999.wav augmented, False
# Augmentation completed. Augmented files are saved in /home/jupyter/augmentedaudio
