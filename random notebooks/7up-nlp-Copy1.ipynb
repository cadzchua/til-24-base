# %% [markdown]
# ## Imports

# %%
import jsonlines
import torchaudio
from datasets import Dataset
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor, Trainer, TrainingArguments, AutoModelForSequenceClassification, EarlyStoppingCallback, TrainerCallback
from pathlib import Path
import torch, random
import librosa, os
import IPython.display as ipd
from dotenv import load_dotenv
import evaluate
from spellchecker import SpellChecker
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union
from datasets import load_metric
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Dataset

# %%
load_dotenv()

TEAM_NAME = os.getenv("TEAM_NAME", "7up")
TEAM_TRACK = os.getenv("TEAM_TRACK", "advanced")


input_dir = Path(f"/home/jupyter/{TEAM_TRACK}")
# input_dir = Path(f"../../data/{TEAM_TRACK}/train")
results_dir = Path(f"/home/jupyter/{TEAM_NAME}")
# results_dir = Path("results")
results_dir.mkdir(parents=True, exist_ok=True)


data = []
with jsonlines.open(input_dir / "nlp.jsonl") as reader:
    for obj in reader:
        data.append(obj)

df = pd.DataFrame(data)

df
# Out:
#        key                                         transcript  \
# 0        0  Turret, prepare to deploy electromagnetic puls...
# 1        1  Engage yellow drone with surface-to-air missil...
# 2        2  Control to turrets, deploy electromagnetic pul...
# 3        3  Alfa, Echo, Mike Papa, deploy EMP tool heading...
# 4        4  Engage the grey, black, and green fighter plan...
# ...    ...                                                ...
# 3495  3495  Deploy electromagnetic pulse on brown commerci...
# 3496  3496  Deploy surface-to-air missiles, heading two on...
# 3497  3497  Engage target, grey, orange, and silver missil...
# 3498  3498  Engage the white drone at heading zero five fi...
# 3499  3499  Turret Charlie, prepare to engage. Deploy EMP ...
#
#                          tool heading                                target
# 0       electromagnetic pulse     065            grey and white fighter jet
# 1     surface-to-air missiles     235                          yellow drone
# 2       electromagnetic pulse     110            blue and red fighter plane
# 3                         EMP     085   purple, red, and silver fighter jet
# 4                 machine gun     095  grey, black, and green fighter plane
# ...                       ...     ...                                   ...
# 3495    electromagnetic pulse     350             brown commercial aircraft
# 3496  surface-to-air missiles     215  silver, orange, and brown helicopter
# 3497  surface-to-air missiles     080      grey, orange, and silver missile
# 3498              machine gun     055                           white drone
# 3499                      EMP     255                  white cargo aircraft
#
# [3500 rows x 5 columns]

# %%
seed = 42

train_df, temp_df = train_test_split(df, test_size=0.2, random_state=seed, shuffle=True)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=seed, shuffle=True)

# Display the resulting DataFrames
print("Training Set:")
train_df
# Out:
# Training Set:
#        key                                         transcript  \
# 162    162  Control tower to turrets, deploy drone catcher...
# 1001  1001  Control to turrets, we have a purple light air...
# 1718  1718  Control tower to turrets, deploy EMP, target t...
# 1003  1003  Turret Bravo, engage silver, red, and yellow m...
# 1233  1233  Engage target, white, purple, and black missil...
# ...    ...                                                ...
# 1095  1095  Deploy surface-to-air missiles to intercept an...
# 1130  1130  Tower to turrets, heading zero seven zero. Dep...
# 1294  1294  Deploy anti-air artillery to intercept green a...
# 860    860  Engage orange fighter plane with machine gun, ...
# 3174  3174  Control, deploy electromagnetic pulse towards ...
#
#                          tool heading                            target
# 162             drone catcher     095                        blue drone
# 1001    electromagnetic pulse     340             purple light aircraft
# 1718                      EMP     045       blue and purple fighter jet
# 1003              machine gun     235   silver, red, and yellow missile
# 1233       anti-air artillery     175  white, purple, and black missile
# ...                       ...     ...                               ...
# 1095  surface-to-air missiles     285             yellow cargo aircraft
# 1130    electromagnetic pulse     070        white and green helicopter
# 1294       anti-air artillery     065   green and purple light aircraft
# 860               machine gun     295              orange fighter plane
# 3174    electromagnetic pulse     295   black and purple cargo aircraft
#
# [2800 rows x 5 columns]

# %%
import torch
from transformers import BertTokenizer, BertForQuestionAnswering

# Load a pre-trained BERT model and tokenizer
model_name = 'bert-large-uncased-whole-word-masking-finetuned-squad'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForQuestionAnswering.from_pretrained(model_name)

# Define the question and context
question = "What is the aircraft to lock?"
context = "Air defense turret, lock onto target black and yellow missile at heading zero one five. Deploy EMP."

# Encode the question and context so that they are prepared for the model
inputs = tokenizer.encode_plus(question, context, return_tensors='pt', add_special_tokens=True)

# Get model's prediction
input_ids = inputs['input_ids']
token_type_ids = inputs['token_type_ids']

# Model output handling might require adjustment based on transformers version
outputs = model(input_ids, token_type_ids=token_type_ids)
start_scores = outputs.start_logits
end_scores = outputs.end_logits

# Find the position tokens with the highest scores
start_index = torch.argmax(start_scores)
end_index = torch.argmax(end_scores) + 1

# Convert tokens to the answer string
answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[0][start_index:end_index]))

print("Answer:", answer)
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Answer: target black and yellow missile

# %%
def heading_text_to_string(heading_text):
    """
    Convert heading text to string representation with leading zeros.
    
    Args:
        heading_text (str): Heading text in format "zero six five".
    
    Returns:
        str: String representation of the heading with leading zeros.
    """
    # Define a mapping from text to integer representations
    heading_mapping = {
        "zero": "0", "one": "1", "two": "2", "three": "3", "four": "4",
        "five": "5", "six": "6", "seven": "7", "eight": "8", "nine": "9", "niner": "9"
    }
    
    # Split the heading text into words and convert each word to its integer representation
    words = heading_text.split()
    string_heading = ""
    for word in words:
        if word in heading_mapping:
            string_heading += heading_mapping[word]
    
    return string_heading

# Test the function
heading_text = "zero niner five"
heading_string = heading_text_to_string(heading_text)
print("Heading String:", heading_string)
# Out:
# Heading String: 095

# %%
def tool_text_to_string(tool):
    if tool == "emp tool" or tool == "emp":
        return "EMP"
    else:
        return tool

# %%
import string
count = 0
for index, row in df.iterrows():
    if row['key'] > 1000:
        
        break
    if row['key'] > -1:
        context = row['transcript'].lower()

        # Answers

        # print(context)
        context=remove_words(context)
        # print(context)
        # translator = str.maketrans('', '', string.punctuation + '-,')

        # Remove all punctuation using translate()
        # context = context.translate(translator)
        heading = predict_answer("What is the heading at?", context)
        # print(heading)
        context_heading=context.replace(heading, '')
        context_heading=context_heading.replace("heading ", '')
        # print(context_heading)
        heading = heading_text_to_string(heading)
        
        color = predict_answer("what is the colors?", context_heading)
        # print(color)
        target = predict_answer("Deploy engagement on what camouflage target?", context_heading)
        # print(target)
        
        if color == target:
            target = predict_answer("What is the flying target", context_heading) 
        if not re.search(r'\b' + re.escape(color) + r'\b', target):
            target = color + " " + target
            
        context_target=context_heading.replace(target, '')
        
        tool = predict_answer("What tool to deploy?", context_target)
        # print(context_tool)
        # print("\n")
        tool = tool_text_to_string(tool)
        
        
        

#         if "jet" not in target:
#             target = predict_answer("what aircraft?", context)
        
#         if "aircraft" not in target:
#             target = predict_answer("what missle?", context)
        
#         if "missle" not in target:
#             target = predict_answer("what drone?", context)
        
        target = target.replace(" , ", ", ")
        target = target.replace("the ", "")
        target = target.replace("a ", "")
        target = target.replace("an ", "")
        target = target.replace("engage ", "")
        tool = tool.replace(" - ", "-")
        tool = tool.replace(" target", "")
        tool = tool.replace(" system", "")
        # Print types and values
        if not heading == row['heading']:
            print(context)
            print(f'Predicted heading: {heading}', f"Actual: {row['heading']}", heading == row['heading'])
            count += 1
        if not target == row['target']:
            print(context_heading)
            print(f'Predicted target: {target}', f"Actual: {row['target']}", target == row['target'])
            count += 1
        if not tool == row['tool']:
            print(context_target)
            print(f'Predicted tool: {tool}', f"Actual: {row['tool']}", tool == row['tool'])
            count += 1
print(count, count/1000)
# Out:
#  to interceptors, deploy interceptor jets immediately. target is an orange and yellow fighter jet . engage and intercept the target. repeat, engage and intercept the target. .
# Predicted target: target is orange and yellow fighter jet Actual: orange and yellow fighter jet False
# control calling  , be advised, deploy surface-to-air missiles, , engage . execute immediately. .
# Predicted tool: control calling Actual: surface-to-air missiles False
# activate machine gun, , engage grey, black, and orange missile.
# Predicted tool: machine gun , , engage grey , black , and orange missile Actual: machine gun False
# deploy surface-to-air missiles, , engage blue, grey, and orange missile.
# Predicted target: surface - to - air missiles, , blue, grey, and orange missile Actual: blue, grey, and orange missile False
# air defense , deploy interceptor jets to . engage the yellow, red, and silver fighter plane.
# Predicted tool: air defense Actual: interceptor jets False
# deploy interceptor jets, , intercept orange, white, and blue fighter plane.
# Predicted target: deploy interceptor jets, , intercept orange, white, and blue fighter plane Actual: orange, white, and blue fighter plane False
# engage target, silver, green, and orange cargo aircraft, with emp. .
# Predicted tool: target Actual: EMP False
# control to air defense s, we have a red fighter jet approaching on a of . deploy emp immediately. .
# Predicted target: red of Actual: red fighter jet False
# air defense , deploy emp on red, purple, and silver fighter jet .
# Predicted tool: air defense Actual: EMP False
#   deploy drone catcher to intercept grey, silver, and red drone at .
# Predicted target: drone catcher to intercept grey, silver, and red drone Actual: grey, silver, and red drone False
# deploy interceptor jets immediately. target is grey and orange fighter plane . engage and neutralize the threat.
# Predicted target: target is grey and orange fighter plane Actual: grey and orange fighter plane False
# control to air defense s, deploy interceptor jets to , engage . .
# Predicted tool: air defense s , deploy interceptor jets Actual: interceptor jets False
#  to air defense s, deploy emp on , targeting .
# Predicted tool: emp on ,ing Actual: EMP False
# control transmitting, target at , engage with machine gun, white, grey, and purple helicopter. .
# Predicted tool: helicopter Actual: machine gun False
#  to s, deploy emp, , target is yellow, purple, and red helicopter.
# Predicted tool: helicopter Actual: EMP False
# fire electromagnetic pulse at  to neutralize .
# Predicted tool: fire electromagnetic pulse Actual: electromagnetic pulse False
# deploy emp, target  .
# Predicted tool: emp , Actual: EMP False
# fire electromagnetic pulse at  to intercept .
# Predicted tool: fire electromagnetic pulse Actual: electromagnetic pulse False
# engage black, red, and purple missile at  with surface-to-air missiles.
# Predicted target: black, red, and purple surface - to - air missiles Actual: black, red, and purple missile False
# control to air defense s, prepare to deploy machine gun tool on target orange and red light aircraft at . engage immediately.
# Predicted target: orange and red orange Actual: orange and red light aircraft False
# control to air defense s, prepare to deploy machine gun tool on target orange and red light aircraft at . engage immediately.
# Predicted tool: machine gun tool Actual: machine gun False
# engage green and silver light aircraft at  using machine gun.
# Predicted target: green and silver light aircraft at using machine gun Actual: green and silver light aircraft False
# control to air defense s, we have an orange, black, and white commercial aircraft at . deploy emp tool for interception. repeat, deploy emp tool for interception. .
# Predicted target: orange, black, and white orange Actual: orange, black, and white commercial aircraft False
# air defense , deploy emp on  at .
# Predicted tool: air defense Actual: EMP False
#   , deploy emp on target, .
# Predicted tool: emp on Actual: EMP False
# deploy emp on the green, brown, and blue drone cluster at .
# Predicted target: green, brown, and blue drone cluster Actual: green, brown, and blue drone False
# engage hostile target, white, orange, and silver light aircraft, , deploy surface-to-air missiles.
# Predicted target: hostile target, white, orange, and silver light aircraft Actual: white, orange, and silver light aircraft False
# air defense , adjust to . target the  and deploy emp.
# Predicted tool: air defense Actual: EMP False
# control to s, this is a  heading. prepare to engage the  utilizing the machine gun tool. repeat, prepare to engage the  with the machine gun tool. .
# Predicted tool: machine gun tool Actual: machine gun False
# engage target, black, white, and brown helicopter, at , with machine gun fire.
# Predicted tool: helicopter Actual: machine gun False
# engage target at . deploy emp on white, orange, and silver light aircraft.
# Predicted target: white, orange, and silver at Actual: white, orange, and silver light aircraft False
# engage, purple, green, and silver fighter plane at  with interceptor jets.
# Predicted target: engage, purple, green, and silver fighter plane at with interceptor jets Actual: purple, green, and silver fighter plane False
# engage orange missile with machine gun, .
# Predicted target: orange missile with machine gun Actual: orange missile False
# , .
# Predicted tool: [SEP] Actual: machine gun False
# engage, yellow, orange, and silver missile with anti-air artillery. . target locked. fire at will.
# Predicted target: yellow, orange, and silver  Actual: yellow, orange, and silver missile False
#  to air defense s, engage surface-to-air missiles, , target .
# Predicted tool: air defense s , engage surface-to-air missiles Actual: surface-to-air missiles False
# control calling all air defense s, we have  , deploy interceptor jets immediately. repeat, deploy interceptor jets to intercept the target. .
# Predicted tool: air defense s , we have , deploy interceptor jets Actual: interceptor jets False
# air defense , alter to , deploy emp against . target locked. engage.
# Predicted tool: air defense Actual: EMP False
# engage target, grey and red fighter plane at , deploy electromagnetic pulse.
# Predicted target: grey and red target Actual: grey and red fighter plane False
# air defense , engage interceptor jets to . target is . intercept and neutralize the threat.
# Predicted tool: air defense Actual: interceptor jets False
#  fire emp at  .
# Predicted tool: fire emp Actual: EMP False
# air defense , , engage grey and black missile with machine gun.
# Predicted target: air defense, , grey and black missile Actual: grey and black missile False
#   and   acquire target , engage the yellow and purple missile with surface-to-air missiles. standby for authorization to fire. target neutralization is imminent.
# Predicted target: acquire target, yellow and purple missile with surface - to - air missiles Actual: yellow and purple missile False
# air defense , deploy emp. . target is . engage.
# Predicted tool: air defense Actual: EMP False
# control here, deploy emp on blue, white, and purple light aircraft . that's an order.
# Predicted tool: emp on blue , white , and purple light aircraft Actual: EMP False
# fire emp weapon at  .
# Predicted tool: fire emp weapon Actual: EMP False
# control to all air defense s, we have a white camouflage light aircraft approaching from . deploy emp immediately to neutralize the threat. .
# Predicted target: white camouflage white Actual: white camouflage light aircraft False
# control to all s, deploy emp at  to intercept the . repeat, deploy emp at  to intercept the . .
# Predicted tool: emp at Actual: EMP False
#   scramble interceptor jets, , engage .
# Predicted tool: scramble interceptor jets Actual: interceptor jets False
# focus  to . deploy electromagnetic pulse on the green missile target. engage.
# Predicted target: green missile target Actual: green missile False
# control to air defense s, we have a visual on a purple, yellow, and grey helicopter. i repeat, a purple, yellow, and grey helicopter. deploy electromagnetic pulse weapon immediately and set to . engage target at will. .
# Predicted tool: electromagnetic pulse weapon Actual: electromagnetic pulse False
# air defense , adjust to . deploy emp on . target locked. fire when ready.
# Predicted tool: air defense , adjust to . deploy emp Actual: EMP False
# air defense , lock on to target, brown and yellow fighter jet located at three zero zero, deploy machine gun. engage target.
# Predicted heading:  Actual: 300 False
# control calling all interceptors, this is a directive to deploy interceptor jets to  to intercept the identified . execute immediately. acknowledge receipt of orders. .
# Predicted tool:  Actual: interceptor jets False
# attention , adjust to . deploy emp against the target, a white, grey, and silver helicopter.
# Predicted tool: helicopter Actual: EMP False
# air defense , adjust to . deploy emp on .
# Predicted tool: air defense Actual: EMP False
# attention all s, hostile grey and purple cargo aircraft at . deploy emp immediately. protect the airspace.
# Predicted target: hostile grey and purple cargo aircraft Actual: grey and purple cargo aircraft False
# deploy emp on target, green, white, and black drone, .
# Predicted tool: drone Actual: EMP False
#  to air defense s, deploy interceptor jets to . target is a grey, purple, and red cargo aircraft.
# Predicted tool: air defense s , deploy interceptor jets Actual: interceptor jets False
# control commands, deploy surface-to-air missiles to , targeting the .
# Predicted tool: control commands Actual: surface-to-air missiles False
# air defense , this is military assistant. head zero two zero. deploy emp on orange and red light aircraft. lock on and fire.
# Predicted heading:  Actual: 020 False
#    and  , deploy emp on target orange, green, and blue missile.
# Predicted tool: emp on orange , green , and blue missile Actual: EMP False
# deploy emp on target , .
# Predicted tool: emp on Actual: EMP False
#  to s, scramble emp to , engage yellow, white, and silver missile.
# Predicted tool: missile Actual: EMP False
# air defense , rotate to . deploy surface-to-air missiles on yellow and green fighter plane. engage the target.
# Predicted target: yellow and green target Actual: yellow and green fighter plane False
#  to air defense s, deploy surface-to-air missiles on yellow and grey cargo aircraft .
# Predicted target: surface - to - air missiles on yellow and grey cargo aircraft Actual: yellow and grey cargo aircraft False
# scramble interceptor jets, engaging  at .
# Predicted tool: scramble interceptor jets Actual: interceptor jets False
# air defense , engage the white, black, and purple drone at  using the drone catcher. engage with caution.
# Predicted target: white, black, and purple drone catcher Actual: white, black, and purple drone False
#   engage  at  with machine gun fire.
# Predicted tool: machine gun fire Actual: machine gun False
# deploy emp on target, , .
# Predicted tool: emp on Actual: EMP False
# deploy electromagnetic pulse on brown fighter plane at .
# Predicted target: what is colors ? [SEP] brown fighter plane Actual: brown fighter plane False
#   , deploy emp on red, yellow, and brown missile.
# Predicted tool: emp on red , yellow , and brown missile Actual: EMP False
#   , emp deploy on blue, black, and yellow light aircraft.
# Predicted target: emp deploy on blue, black, and yellow light aircraft Actual: blue, black, and yellow light aircraft False
#   , emp deploy on blue, black, and yellow light aircraft.
# Predicted tool: light aircraft Actual: EMP False
# control to all s, prepare for emp deployment at . target is a yellow and orange camouflage light aircraft. commence operation immediately. .
# Predicted target: yellow and orange Actual: yellow and orange camouflage light aircraft False
# control to all s, prepare for emp deployment at . target is  camouflage light aircraft. commence operation immediately. .
# Predicted tool: camouflage light aircraft Actual: EMP False
#  to air defense s, target one four zero, brown, white, and grey fighter plane. deploy anti-air artillery.
# Predicted heading:  Actual: 140 False
#  , target one four zero, brown, white, and grey fighter plane. deploy anti-air artillery.
# Predicted target: brown, white, and grey one four zero Actual: brown, white, and grey fighter plane False
# deploy drone catcher to intercept grey, red, and blue drone at .
# Predicted target: drone catcher to intercept grey, red, and blue drone Actual: grey, red, and blue drone False
# engage target, , with emp. .
# Predicted tool:  Actual: EMP False
# initiate anti-air artillery deployment on  targeting green, blue, and orange fighter planes.
# Predicted target: green, blue, and orange fighter planes Actual: green, blue, and orange fighter plane False
# control to all air defense s, we have a blue, black, and yellow missile incoming on a of . deploy surface-to-air missiles immediately. repeat, blue, black, and yellow missile at , engage with surface-to-air missiles. .
# Predicted target: blue, black, and yellow of Actual: blue, black, and yellow missile False
# engage orange and red drone with drone catcher, .
# Predicted target: orange and red drone catcher Actual: orange and red drone False
# control to surface-to-air s, shift to . prepare to engage target identified as a silver, blue, and white missile using surface-to-air missiles. execute with precision. .
# Predicted tool: surface-to-air s , shift to . prepare to engage identified as a silver , blue , and white missile using surface-to-air missiles Actual: surface-to-air missiles False
#   deploy emp on target, orange, white, and silver missile, . target locked, awaiting confirmation to engage.
# Predicted tool: emp on , orange , white , and silver missile Actual: EMP False
# activate electromagnetic pulse, , green missile target.
# Predicted target: green missile target Actual: green missile False
#  to all air defense s, prepare to deploy emp. . target is a black, brown, and blue helicopter. engage and eliminate.
# Predicted tool: emp . . is a black , brown , and blue helicopter Actual: EMP False
# air defense , deploy emp on  at .
# Predicted tool: air defense Actual: EMP False
#  to air defense s. intercept purple fighter plane  with interceptor jets. protect airspace. .
# Predicted target: intercept purple fighter plane Actual: purple fighter plane False
#  to s, engage electromagnetic pulse on silver, red, and blue drone .
# Predicted tool: electromagnetic pulse on silver , red , and blue drone Actual: electromagnetic pulse False
# deploy emp.  at .
# Predicted tool: emp . at Actual: EMP False
#  to air defense s, , deploy emp on orange, brown, and red helicopter.
# Predicted tool: emp on orange , brown , and red helicopter Actual: EMP False
#  to all s, deploy emp on target  .
# Predicted tool: emp on Actual: EMP False
# air defense s, engage  at  with emp.
# Predicted tool: air defense s , engage at with emp Actual: EMP False
# air defense s, deploy emp on brown, purple, and orange fighter jet . engage target immediately.
# Predicted tool: air defense s , deploy emp Actual: EMP False
# engage target, silver, white, and green fighter jet, at , with emp.
# Predicted tool: target Actual: EMP False
#  to surface-to-air s, target is a  . deploy surface-to-air missiles now.
# Predicted tool: surface-to-air s , is a . deploy surface-to-air missiles Actual: surface-to-air missiles False
# surface-to-air missiles, lock on and engage the green and brown camouflage commercial aircraft at .
# Predicted target: green and brown commercial aircraft Actual: green and brown camouflage commercial aircraft False
# air defense , adjust to , deploy emp on the .
# Predicted tool: air defense Actual: EMP False
# air defense s, deploy anti-air artillery towards the yellow, orange, and silver drone at . engage and neutralize the target immediately.
# Predicted tool: air defense s , deploy anti-air artillery Actual: anti-air artillery False
# engage orange fighter plane with machine gun, .
# Predicted target: orange fighter plane with machine gun Actual: orange fighter plane False
# engage , .
# Predicted tool: engage Actual: machine gun False
# fire emp at red, black, and silver fighter jet .
# Predicted tool: fighter jet Actual: EMP False
#   fire electromagnetic pulse at the purple, black, and brown cargo aircraft . standby for effect.
# Predicted tool: fire electromagnetic pulse Actual: electromagnetic pulse False
# control here, adjust to . engage purple, orange, and silver drone with machine gun. target in sight, commence firing. .
# Predicted target: purple, orange, and silver  Actual: purple, orange, and silver drone False
# deploy drone catcher, , intercept grey and purple drone.
# Predicted target: drone catcher, , intercept grey and purple drone Actual: grey and purple drone False
# engage, green, silver, and black commercial aircraft at  with surface-to-air missiles.
# Predicted target: engage, green, silver, and black commercial aircraft Actual: green, silver, and black commercial aircraft False
# engage, the white, black, and silver fighter plane at , deploy emp.
# Predicted target: engage, white, black, and silver fighter plane Actual: white, black, and silver fighter plane False
# air defense , target  at , deploy surface-to-air missiles.
# Predicted tool: air defense , at , deploy surface-to-air missiles Actual: surface-to-air missiles False
#   and  s, prepare to engage a blue, silver, and brown missile at  using machine gun fire.
# Predicted tool: machine gun fire Actual: machine gun False
#   engage with machine gun on black, yellow, and silver missile at .
# Predicted target: with machine gun on black, yellow, and silver missile Actual: black, yellow, and silver missile False
#  to air defense s, scramble interceptor jets immediately. red, grey, and black fighter jet, . engage and intercept.
# Predicted tool: scramble interceptor jets Actual: interceptor jets False
# air defense , deploy interceptor jets to . engage the silver, white, and orange cargo aircraft.
# Predicted tool: air defense Actual: interceptor jets False
#  to air defense s, scramble interceptor jets. intercept blue, red, and silver cargo aircraft at .
# Predicted tool: scramble interceptor jets Actual: interceptor jets False
# air defense , adjust to . engage  with emp weapon. target neutralized.
# Predicted tool: emp weapon Actual: EMP False
# control to all s, prepare to engage red, blue, and silver light aircraft at  using surface-to-air missiles. repeat, prepare to engage red, blue, and silver light aircraft at  using surface-to-air missiles. .
# Predicted target: red, blue, and silver  Actual: red, blue, and silver light aircraft False
# lock on . deploy surface-to-air missiles on the yellow, black, and orange missile. engage target.
# Predicted target: yellow, black, and orange target Actual: yellow, black, and orange missile False
# air defense , , target , deploy emp.
# Predicted tool: air defense , , , deploy emp Actual: EMP False
# fire emp at  .
# Predicted tool: fire emp Actual: EMP False
# 119 0.119

# %%
import torch
from transformers import BertTokenizer, BertForQuestionAnswering
import nltk
from nltk.corpus import stopwords
import re

# Load a pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# Function to predict the answer for a single question
def predict_answer(question, context):
    inputs = tokenizer.encode_plus(question, context, return_tensors='pt', add_special_tokens=True)
    input_ids = inputs['input_ids']
    token_type_ids = inputs['token_type_ids']

    outputs = model(input_ids, token_type_ids=token_type_ids)
    start_scores = outputs.start_logits
    end_scores = outputs.end_logits

    start_index = torch.argmax(start_scores)
    end_index = torch.argmax(end_scores) + 1

    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[0][start_index:end_index]))
    return answer

def remove_words(context):
    # Define the patterns to match "Turret", "turret", and "turrets"
    patterns = [r'turret', r'turrets', r'turrets, ', r'control tower,*', r'over', r'tower']
    
    # Compile the patterns into regular expressions
    regex_list = [re.compile(pattern, flags=re.IGNORECASE) for pattern in patterns]

    # Iterate through the regex_list and replace the matches with an empty string
    for regex in regex_list:
        context = regex.sub('', context)
    
    words_to_remove = ["alpha", "alfa", "bravo", "charlie", "delta", "echo", "foxtrot", "golf", "hotel", 
                  "india", "juliet", "kilo", "lima", "mike", "november", "oscar", "papa", 
                  "quebec", "romeo", "sierra", "tango", "uniform", "victor", "whiskey", 
                  "x-ray", "yankee", "zulu"]

    pattern = r'\b(?:' + '|'.join(words_to_remove) + r')(?:,|\b)'
    result = re.sub(pattern, '', context, flags=re.IGNORECASE)

    return result
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import nltk
from nltk.corpus import stopwords

def remove_stopwords_except_and(sentence):
    stop_words = set(stopwords.words("english"))
    words = nltk.word_tokenize(sentence)
    filtered_sentence = [word for word in words if word.lower() not in stop_words or word.lower() == "and"]
    return " ".join(filtered_sentence)

sentence = "I like to dance and sing"
result = remove_stopwords_except_and(sentence)
print(result)
# Out:
# like dance and sing

# %%
import json
from sklearn.model_selection import train_test_split

# Load JSON data
data = []
with open("advanced/nlp.jsonl", 'r') as f:
    for line in f:
        # Load individual JSON object from each line
        obj = json.loads(line)
        data.append(obj)

# %%
# Extract transcripts and labels
texts = [entry["transcript"] for entry in data]
labels = [(entry["tool"], entry["heading"], entry["target"]) for entry in data]

# Split data into training and validation sets
train_texts, val_texts, train_labels, val_labels = train_test_split(texts, labels, test_size=0.2, random_state=42)

# %%
# import torch
# from transformers import BertTokenizer, BertForSequenceClassification, AdamW
# from torch.utils.data import DataLoader, Dataset
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
# model = BertForQuestionAnswering.from_pretrained('bert-base-uncased', force_download=True)
# # Define your dataset class
# class CustomDataset(Dataset):
#     def __init__(self, texts, labels, tokenizer, max_length):
#         self.texts = texts
#         self.labels = labels
#         self.tokenizer = tokenizer
#         self.max_length = max_length

#     def __len__(self):
#         return len(self.texts)

#     def __getitem__(self, idx):
#         text = self.texts[idx]
#         label = self.labels[idx]
    
#         encoding = self.tokenizer.encode_plus(
#             text,
#             add_special_tokens=True,
#             max_length=self.max_length,
#             padding='max_length',
#             truncation=True,
#             return_tensors='pt'
#         )
#         label_encoder = LabelEncoder()

#         # Fit label encoder and transform labels to numerical values
#         label_numeric = label_encoder.fit_transform(label)
#         return {
#             'input_ids': encoding['input_ids'].flatten(),
#             'attention_mask': encoding['attention_mask'].flatten(),
#             'labels': torch.tensor(label_numeric, dtype=torch.long)
#         }
    
# train_dataset = CustomDataset(train_texts, train_labels, tokenizer, max_length=128)
# val_dataset = CustomDataset(val_texts, val_labels, tokenizer, max_length=128)

# # Define dataloaders
# train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# # Define optimizer and learning rate scheduler
# optimizer = AdamW(model.parameters(), lr=2e-5, no_deprecation_warning=True)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)

# # Training loop
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model.to(device)

# num_epochs = 5
# for epoch in range(num_epochs):
#     model.train()
#     for batch in train_loader:
#         input_ids = batch['input_ids'].to(device)
#         attention_mask = batch['attention_mask'].to(device)
#         labels = batch['labels'].to(device)

#         optimizer.zero_grad()
#         outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
#         loss = outputs.loss
#         loss.backward()
#         optimizer.step()
#         scheduler.step()

#     # Validation
#     model.eval()
#     val_loss = 0
#     num_correct = 0
#     total_samples = 0
#     with torch.no_grad():
#         for batch in val_loader:
#             input_ids = batch['input_ids'].to(device)
#             attention_mask = batch['attention_mask'].to(device)
#             labels = batch['labels'].to(device)

#             outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
#             loss = outputs.loss
#             val_loss += loss.item()

#             predictions = torch.argmax(outputs.logits, dim=1)
#             num_correct += (predictions == labels).sum().item()
#             total_samples += labels.size(0)

#     val_loss /= len(val_loader)
#     accuracy = num_correct / total_samples

#     print(f'Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}, Accuracy: {accuracy:.4f}')

# %%
data =[]
with open("advanced/nlp.jsonl", 'r') as f:
    for line in f:
        # Load individual JSON object from each line
        obj = json.loads(line)
        data.append(obj)


# Extract transcripts, headings, tools, and targets from the data
transcripts = []
for item in data:
    transcripts.append({
        'transcript': item['transcript'],
        'heading': item['heading'],
        'tool': item['tool'],
        'target': item['target']
    })

# %%
import torch
from transformers import BertTokenizer, BertForTokenClassification, AdamW
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import LabelEncoder

class CustomDataset(Dataset):
    def __init__(self, transcripts, tokenizer, max_length):
        self.tokenizer = tokenizer
        self.max_length = max_length

        # Convert list of dictionaries to dictionary of lists
        transcripts_dict = {"transcript": [], "heading": [], "tool": [], "target": []}
        for transcript in transcripts:
            for key in transcripts_dict.keys():
                transcripts_dict[key].append(transcript[key])

        # Label encoding
        self.label_encoders = {}
        for key in ['heading', 'tool', 'target']:
            self.label_encoders[key] = LabelEncoder()
            transcripts_dict[key] = self.label_encoders[key].fit_transform(transcripts_dict[key])

        self.transcripts = transcripts_dict

    def __len__(self):
        return len(self.transcripts["transcript"])

    def __getitem__(self, idx):
        transcript = {key: self.transcripts[key][idx] for key in self.transcripts.keys()}
        
        # Tokenize the transcript
        encoding = self.tokenizer(transcript["transcript"], padding='max_length', truncation=True, max_length=self.max_length, return_tensors='pt')
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor([transcript["heading"], transcript["tool"], transcript["target"]])  # Stacking along dimension 0
        }

# Initialize tokenizer and dataset
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
train_dataset = CustomDataset(transcripts, tokenizer, max_length=128)

# Define dataloaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# Instantiate BertForTokenClassification
model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=3)  # 3 labels: heading, tool, target

# Define optimizer
optimizer = AdamW(model.parameters(), lr=2e-5)

# Training loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_epochs = 5
for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        
        # Print the shape of the logits and the labels
        print("Logits shape:", outputs.logits.shape)
        print("Labels shape:", labels.shape)
        
        loss = outputs.loss
        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}/{num_epochs} completed')
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:521: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 65
#      62 labels = batch['labels'].to(device)
#      64 optimizer.zero_grad()
# ---> 65 outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
#      67 # Print the shape of the logits and the labels
#      68 print("Logits shape:", outputs.logits.shape)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1753, in BertForTokenClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1751 if labels is not None:
#    1752     loss_fct = CrossEntropyLoss()
# -> 1753     loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
#    1755 if not return_dict:
#    1756     output = (logits,) + outputs[2:]
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/loss.py:1185, in CrossEntropyLoss.forward(self, input, target)
#    1184 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1185     return F.cross_entropy(input, target, weight=self.weight,
#    1186                            ignore_index=self.ignore_index, reduction=self.reduction,
#    1187                            label_smoothing=self.label_smoothing)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:3086, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3084 if size_average is not None or reduce is not None:
#    3085     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3086 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# ValueError: Expected input batch_size (2048) to match target batch_size (48).
